# %%
! pip install ffmpeg-python
# Out:
# Collecting ffmpeg-python
#   Using cached https://files.pythonhosted.org/packages/d7/0c/56be52741f75bad4dc6555991fabd2e07b432d333da82c11ad701123888a/ffmpeg_python-0.2.0-py3-none-any.whl
# Requirement already satisfied: future in /Users/sjegan/anaconda3/lib/python3.7/site-packages (from ffmpeg-python) (0.17.1)
# Installing collected packages: ffmpeg-python
# Successfully installed ffmpeg-python-0.2.0

# %%
from os import listdir
import os
from os.path import isfile, join
import shutil

def tomp4(input_file, output_file):
    import ffmpy

    # input_file = "/Users/sjegan/Downloads/untitled folder 3/S04E15.mkv"
    # output_file = "/Users/sjegan/Downloads/Output.mp4"
    crf = 18

    input_name = input_file
    output_name = output_file
    inp={input_name:None}
    outp = {output_name:'-vcodec libx264 -crf 28 -preset faster -tune film -strict -2 -filter:v scale="640:trunc(ow/a/2)*2" -b:v 128k -b:a 100k -r 20 '}
    outp = {output_name:'-af apad -shortest -avoid_negative_ts make_zero -fflags +genpts -vcodec libx264 -acodec aac -preset faster -tune film -strict -2 -filter:v scale="640:trunc(ow/a/2)*2" -b:v 128k -b:a 100k -r 20 -framerate 20 '}
    ff=ffmpy.FFmpeg(inputs=inp,outputs=outp)
    print(ff.cmd) # just to verify that it produces the correct ffmpeg command
    ff.run()
    import os
    # os.system(ff.cmd)
#     print("done!")

dir_name = "/Users/sjegan/Downloads/concat"
dest_dir_name = "/Users/sjegan/Downloads/dest"
bin_dir_name = "/Users/sjegan/Downloads/dest/del"

onlyfiles = [(join(dir_name, f), f) for f in listdir(dir_name) if isfile(join(dir_name, f))]
# print(onlyfiles)
totalfiles = len(onlyfiles)
onlyfiles.sort()
i=1
onlyfiles.sort
for loc, filename in onlyfiles:
    if loc.endswith(".avi") or loc.endswith(".mp4") or loc.endswith(".MP4") or loc.endswith(".mkv") or loc.endswith(".mpg"):
        cmd_filelist = "C:\\Users\\Jegan\\Downloads\\ffmpeg\\bin\\ffmpeg.exe -i \"" + loc + "\" -filter:v scale=\"640:trunc(ow/a/2)*2\" -b:v 128k -b:a 100k -r 20 \"" + dest_dir_name + filename + ".mp4\""
        tomp4(loc, dest_dir_name + "/" + os.path.splitext(os.path.basename(filename))[0] + ".mp4")
        print(cmd_filelist)
        print(f'-------------------{i} / {totalfiles}----------------------')
        shutil.move(src=loc, dst=bin_dir_name)
        i = i + 1
    #     os.system(cmd_filelist)

# ffmpeg -i segment1.mov -af apad -c:v copy <audio encoding params> -shortest -avoid_negative_ts make_zero -fflags +genpts padded1.mov
# Out:
# ffmpeg -i "/Users/sjegan/Downloads/concat/S01E01 Off the Baa.mp4" -af apad -shortest -avoid_negative_ts make_zero -fflags +genpts -vcodec libx264 -acodec aac -preset faster -tune film -strict -2 -filter:v scale=640:trunc(ow/a/2)*2 -b:v 128k -b:a 100k -r 20 -framerate 20 "/Users/sjegan/Downloads/dest/S01E01 Off the Baa.mp4"
# C:\Users\Jegan\Downloads\ffmpeg\bin\ffmpeg.exe -i "/Users/sjegan/Downloads/concat/S01E01 Off the Baa.mp4" -filter:v scale="640:trunc(ow/a/2)*2" -b:v 128k -b:a 100k -r 20 "/Users/sjegan/Downloads/destS01E01 Off the Baa.mp4.mp4"
# -------------------1 / 156----------------------
# ffmpeg -i "/Users/sjegan/Downloads/concat/S01E02 Bathtime.mp4" -af apad -shortest -avoid_negative_ts make_zero -fflags +genpts -vcodec libx264 -acodec aac -preset faster -tune film -strict -2 -filter:v scale=640:trunc(ow/a/2)*2 -b:v 128k -b:a 100k -r 20 -framerate 20 "/Users/sjegan/Downloads/dest/S01E02 Bathtime.mp4"
# C:\Users\Jegan\Downloads\ffmpeg\bin\ffmpeg.exe -i "/Users/sjegan/Downloads/concat/S01E02 Bathtime.mp4" -filter:v scale="640:trunc(ow/a/2)*2" -b:v 128k -b:a 100k -r 20 "/Users/sjegan/Downloads/destS01E02 Bathtime.mp4.mp4"
# -------------------2 / 156----------------------
# ffmpeg -i "/Users/sjegan/Downloads/concat/S01E03 Shape Up with Shaun.mp4" -af apad -shortest -avoid_negative_ts make_zero -fflags +genpts -vcodec libx264 -acodec aac -preset faster -tune film -strict -2 -filter:v scale=640:trunc(ow/a/2)*2 -b:v 128k -b:a 100k -r 20 -framerate 20 "/Users/sjegan/Downloads/dest/S01E03 Shape Up with Shaun.mp4"
# C:\Users\Jegan\Downloads\ffmpeg\bin\ffmpeg.exe -i "/Users/sjegan/Downloads/concat/S01E03 Shape Up with Shaun.mp4" -filter:v scale="640:trunc(ow/a/2)*2" -b:v 128k -b:a 100k -r 20 "/Users/sjegan/Downloads/destS01E03 Shape Up with Shaun.mp4.mp4"
# -------------------3 / 156----------------------
# ffmpeg -i "/Users/sjegan/Downloads/concat/S01E04 Timmy in a Tizzy.mp4" -af apad -shortest -avoid_negative_ts make_zero -fflags +genpts -vcodec libx264 -acodec aac -preset faster -tune film -strict -2 -filter:v scale=640:trunc(ow/a/2)*2 -b:v 128k -b:a 100k -r 20 -framerate 20 "/Users/sjegan/Downloads/dest/S01E04 Timmy in a Tizzy.mp4"
# C:\Users\Jegan\Downloads\ffmpeg\bin\ffmpeg.exe -i "/Users/sjegan/Downloads/concat/S01E04 Timmy in a Tizzy.mp4" -filter:v scale="640:trunc(ow/a/2)*2" -b:v 128k -b:a 100k -r 20 "/Users/sjegan/Downloads/destS01E04 Timmy in a Tizzy.mp4.mp4"
# -------------------4 / 156----------------------
# ffmpeg -i "/Users/sjegan/Downloads/concat/S01E05 Scrumping.mp4" -af apad -shortest -avoid_negative_ts make_zero -fflags +genpts -vcodec libx264 -acodec aac -preset faster -tune film -strict -2 -filter:v scale=640:trunc(ow/a/2)*2 -b:v 128k -b:a 100k -r 20 -framerate 20 "/Users/sjegan/Downloads/dest/S01E05 Scrumping.mp4"
# C:\Users\Jegan\Downloads\ffmpeg\bin\ffmpeg.exe -i "/Users/sjegan/Downloads/concat/S01E05 Scrumping.mp4" -filter:v scale="640:trunc(ow/a/2)*2" -b:v 128k -b:a 100k -r 20 "/Users/sjegan/Downloads/destS01E05 Scrumping.mp4.mp4"
# -------------------5 / 156----------------------
# ffmpeg -i "/Users/sjegan/Downloads/concat/S01E06 Still Life.mp4" -af apad -shortest -avoid_negative_ts make_zero -fflags +genpts -vcodec libx264 -acodec aac -preset faster -tune film -strict -2 -filter:v scale=640:trunc(ow/a/2)*2 -b:v 128k -b:a 100k -r 20 -framerate 20 "/Users/sjegan/Downloads/dest/S01E06 Still Life.mp4"
# C:\Users\Jegan\Downloads\ffmpeg\bin\ffmpeg.exe -i "/Users/sjegan/Downloads/concat/S01E06 Still Life.mp4" -filter:v scale="640:trunc(ow/a/2)*2" -b:v 128k -b:a 100k -r 20 "/Users/sjegan/Downloads/destS01E06 Still Life.mp4.mp4"
# -------------------6 / 156----------------------
# ffmpeg -i "/Users/sjegan/Downloads/concat/S01E07 Mower Mouth.mp4" -af apad -shortest -avoid_negative_ts make_zero -fflags +genpts -vcodec libx264 -acodec aac -preset faster -tune film -strict -2 -filter:v scale=640:trunc(ow/a/2)*2 -b:v 128k -b:a 100k -r 20 -framerate 20 "/Users/sjegan/Downloads/dest/S01E07 Mower Mouth.mp4"
# C:\Users\Jegan\Downloads\ffmpeg\bin\ffmpeg.exe -i "/Users/sjegan/Downloads/concat/S01E07 Mower Mouth.mp4" -filter:v scale="640:trunc(ow/a/2)*2" -b:v 128k -b:a 100k -r 20 "/Users/sjegan/Downloads/destS01E07 Mower Mouth.mp4.mp4"
# -------------------7 / 156----------------------
# ffmpeg -i "/Users/sjegan/Downloads/concat/S01E08 Take Away.mp4" -af apad -shortest -avoid_negative_ts make_zero -fflags +genpts -vcodec libx264 -acodec aac -preset faster -tune film -strict -2 -filter:v scale=640:trunc(ow/a/2)*2 -b:v 128k -b:a 100k -r 20 -framerate 20 "/Users/sjegan/Downloads/dest/S01E08 Take Away.mp4"
# C:\Users\Jegan\Downloads\ffmpeg\bin\ffmpeg.exe -i "/Users/sjegan/Downloads/concat/S01E08 Take Away.mp4" -filter:v scale="640:trunc(ow/a/2)*2" -b:v 128k -b:a 100k -r 20 "/Users/sjegan/Downloads/destS01E08 Take Away.mp4.mp4"
# -------------------8 / 156----------------------
# ffmpeg -i "/Users/sjegan/Downloads/concat/S01E09 The Bull.mp4" -af apad -shortest -avoid_negative_ts make_zero -fflags +genpts -vcodec libx264 -acodec aac -preset faster -tune film -strict -2 -filter:v scale=640:trunc(ow/a/2)*2 -b:v 128k -b:a 100k -r 20 -framerate 20 "/Users/sjegan/Downloads/dest/S01E09 The Bull.mp4"
# C:\Users\Jegan\Downloads\ffmpeg\bin\ffmpeg.exe -i "/Users/sjegan/Downloads/concat/S01E09 The Bull.mp4" -filter:v scale="640:trunc(ow/a/2)*2" -b:v 128k -b:a 100k -r 20 "/Users/sjegan/Downloads/destS01E09 The Bull.mp4.mp4"
# -------------------9 / 156----------------------
# ffmpeg -i "/Users/sjegan/Downloads/concat/S01E10 Saturday Night Shaun.mp4" -af apad -shortest -avoid_negative_ts make_zero -fflags +genpts -vcodec libx264 -acodec aac -preset faster -tune film -strict -2 -filter:v scale=640:trunc(ow/a/2)*2 -b:v 128k -b:a 100k -r 20 -framerate 20 "/Users/sjegan/Downloads/dest/S01
lyfiles = [(join(dir_name, f), f) for f in listdir(dir_name) if isfile(join(dir_name, f))]
onlyfiles.sort()
for loc, filename in onlyfiles:
    if loc.endswith(".mp4"):
        files.append(loc)
files.sort()

i = 1

file_list = open(video_files, "w")
for f in files:
    file_list.write("file '%s'\n" % f)
file_list.close()

# merge the video files
cmd = ["ffmpeg",
       "-f",
       "concat",
       "-safe",
       "0",
       "-loglevel",
       "quiet",
       "-i",
       "%s" % video_files,
       "-c",
       "copy",
       "%s" % output_file
       ]




p = subprocess.Popen(cmd, stdin=subprocess.PIPE)

fout = p.stdin
fout.close()
p.wait()

print(p.returncode)
# Out:
# 0

# %%
import os
import subprocess
import time
from os import listdir
import os
from os.path import isfile, join
import shutil

dir_name = "/Users/sjegan/Downloads/concat"
dest_dir_name = "/Users/sjegan/Downloads/dest"
bin_dir_name = "/Users/sjegan/Downloads/dest/del"

base_dir = dir_name
video_files = "/Users/sjegan/Downloads/video_list.txt"
output_file = "/Users/sjegan/Downloads/output.mp4"


files = []
onlyfiles = [(join(dir_name, f), f) for f in listdir(dir_name) if isfile(join(dir_name, f))]
onlyfiles.sort()
for loc, filename in onlyfiles:
    if loc.endswith(".mp4"):
        files.append(loc)
files.sort()

# %%
s = ""
for f in files:
    s += " \""+f+"\" "
cm = f"cat {s} > /Users/sjegan/Downloads/output.mp4"
cm
os.system(cm)
# Out:
# 0

# %%
import os
import subprocess
import time
from os import listdir
import os
from os.path import isfile, join
import shutil

dir_name = "/Users/sjegan/Downloads/concat"
dest_dir_name = "/Users/sjegan/Downloads/dest"
bin_dir_name = "/Users/sjegan/Downloads/dest/del"

base_dir = dir_name
video_files = "/Users/sjegan/Downloads/video_list.txt"
output_file = "/Users/sjegan/Downloads/output.mp4"


files = []
onlyfiles = [(join(dir_name, f), f) for f in listdir(dir_name) if isfile(join(dir_name, f))]
onlyfiles.sort()
for loc, filename in onlyfiles:
    if loc.endswith(".mp4"):
        files.append(loc)
files.sort()


from moviepy.editor import *
for f in files:
    video = VideoFileClip(f)
    audio = video.audio
    duration = video.duration # == audio.duration, presented in seconds, float
    #note video.fps != audio.fps
    step = 0.1
    shit = 0
    for t in range(int(duration / step)): # runs through audio/video frames obtaining them by timestamp with step 100 msec
        t = t * step
        if t > audio.duration or t > video.duration:
            shit = 1
            break
        audio_frame = audio.get_frame(t) #numpy array representing mono/stereo values
        video_frame = video.get_frame(t) #numpy array representing RGB/gray frame
    if shit == 1:
        print(f"Something Wrong {f}")
    else:
        print(f"Fine {f}")
# Out:
# Fine /Users/sjegan/Downloads/concat/S01E01 Off the Baa.mp4
# Fine /Users/sjegan/Downloads/concat/S01E02 Bathtime.mp4
# Fine /Users/sjegan/Downloads/concat/S01E03 Shape Up with Shaun.mp4
# Fine /Users/sjegan/Downloads/concat/S01E04 Timmy in a Tizzy.mp4
# Fine /Users/sjegan/Downloads/concat/S01E05 Scrumping.mp4
# Fine /Users/sjegan/Downloads/concat/S01E06 Still Life.mp4
# Fine /Users/sjegan/Downloads/concat/S01E07 Mower Mouth.mp4
# Fine /Users/sjegan/Downloads/concat/S01E08 Take Away.mp4
# Fine /Users/sjegan/Downloads/concat/S01E09 The Bull.mp4
# Fine /Users/sjegan/Downloads/concat/S01E10 Saturday Night Shaun.mp4
# Fine /Users/sjegan/Downloads/concat/S01E11 The Kite.mp4
# Fine /Users/sjegan/Downloads/concat/S01E12 Little Sheep of Horrors.mp4
# Fine /Users/sjegan/Downloads/concat/S01E13 Buzz Off Bees.mp4
# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-9eb8faf78cdf> in <module>
# ----> 1 video_frame
#
# NameError: name 'video_frame' is not defined

# %%
# Out:
# ['/Users/sjegan/Downloads/concat/shaun010.mp4',
#  '/Users/sjegan/Downloads/concat/shaun020.mp4',
#  '/Users/sjegan/Downloads/concat/shaun030.mp4',
#  '/Users/sjegan/Downloads/concat/shaun040.mp4',
#  '/Users/sjegan/Downloads/concat/shaun050.mp4',
#  '/Users/sjegan/Downloads/concat/shaun060.mp4',
#  '/Users/sjegan/Downloads/concat/shaun070.mp4',
#  '/Users/sjegan/Downloads/concat/shaun080.mp4',
#  '/Users/sjegan/Downloads/concat/shaun090.mp4',
#  '/Users/sjegan/Downloads/concat/shaun100.mp4',
#  '/Users/sjegan/Downloads/concat/shaun110.mp4',
#  '/Users/sjegan/Downloads/concat/shaun120.mp4',
#  '/Users/sjegan/Downloads/concat/shaun130.mp4',
#  '/Users/sjegan/Downloads/concat/shaun140.mp4',
#  '/Users/sjegan/Downloads/concat/shaun150.mp4']

# %%
# Out:
# 0
# 0
# 0
# 0
# 0

# %%
import pyunpack
from os import listdir
import os
from os.path import isfile, join
import shutil

from unrar import rarfile
import os
import subprocess
import time
from os import listdir
import os
from os.path import isfile, join
import shutil
import glob, os

def convertByPIL(source, destination, small=False):
    from PIL import Image
    image = Image.open(source)
    w1 = image.width
    h1 = image.height
    h2 = 1024
    if(small == True):
        h2 = 512
    w2 = int((w1*h2)/h1)
    newImage = image.resize((w2, h2), Image.NEAREST)
    os.remove(source)
    newImage.save(destination)

def convertByScipy(source, destination, small=False):
    import scipy.misc
    import numpy as np
    img = scipy.misc.imread(imgpath)
    assert len(img.shape) == 3
    w1 = img.shape[0]
    h1 = img.shape[1]
    h2 = 1024
    w2 = int((w1*h2)/h1)

    if small == True:
        if w2 > h2:
            h2 = 512
            w2 = int((w1*h2)/h1)
    img_resized = scipy.misc.imresize(img, (w2, h2))
    img_answer = (img_resized/255.0).astype('float32')

    import matplotlib.pyplot as plt
#     plt.imshow(np.uint8(img))
#     plt.show()
#     plt.imshow(np.uint8(img_resized))
#     plt.show()
    os.remove(source)
    scipy.misc.imsave(destination, img_resized)

def convertImage(source, destination, small=False, delfol = "/Users/sjegan/Downloads/del/"):
    import scipy
    imgpath = source
    try:
        convertByScipy(source, destination, small)
    except:
        try:
            convertByPIL(source, destination, small)
        except:
            print(f'Error in Conversion - {source}')
            shutil.move(src=source, dst=delfol)

def convertAllImages(files, small=False):
    for f in files:
        convertImage(f, f'{f[0:-4]}.jpg', small)

def getListOfFiles(dirName, filterlist):
    listOfFile = os.listdir(dirName)
    allFiles = list()
    for entry in listOfFile:
        fullPath = os.path.join(dirName, entry)
        if os.path.isdir(fullPath):
            allFiles = allFiles + getListOfFiles(fullPath, filterlist)
        else:
            canadd = False
            for f in filterlist:
                if fullPath.endswith(f):
                    allFiles.append(fullPath)
                    break
    allFiles.sort()
                
    return allFiles
def shrinkImages(dir_name):
    from webptools import webplib as webp
    webpFiles = getListOfFiles(dir_name, ['webp'])
    for (w) in webpFiles:
#         webp.dwebp(w,f'{w}.jpg',"-o")
        os.system(f'dwebp "{w}" -o "{w}.jpg"')
        os.remove(w)
    files = getListOfFiles(dir_name, ['jpg', 'jpeg', 'JPEG', 'JPG', 'png', 'PNG'])
    convertAllImages(files, False)

def tomp4(input_file, output_file):
    import ffmpy
    crf = 18
    input_name = input_file
    output_name = output_file
    inp={input_name:None}
    outp = {output_name:'-vcodec libx264 -crf 28 -preset faster -tune film -strict -2 -filter:v scale="640:trunc(ow/a/2)*2" -b:v 128k -b:a 100k -r 20 '}
    outp = {output_name:'-af apad -shortest -avoid_negative_ts make_zero -fflags +genpts -vcodec libx264 -acodec aac -preset faster -tune film -strict -2 -filter:v scale="640:trunc(ow/a/2)*2" -b:v 128k -b:a 100k -r 20 '}
    ff=ffmpy.FFmpeg(inputs=inp,outputs=outp)
    print(ff.cmd) # just to verify that it produces the correct ffmpeg command
    ff.run()

from os import listdir
import os
import ffmpy
from os.path import isfile, join
import shutil

def shrinkVideos(dir_name, dest_dir_name, bin_dir_name):
    onlyfiles = [(join(dir_name, f), f) for f in listdir(dir_name) if isfile(join(dir_name, f))]
    totalfiles = len(onlyfiles)
    onlyfiles.sort()
    i=1
    onlyfiles.sort
    for loc, filename in onlyfiles:
        if loc.endswith(".avi") or loc.endswith(".mp4") or loc.endswith(".MP4") or loc.endswith(".mkv") or loc.endswith(".mpg") or loc.endswith(".flv"):
            cmd_filelist = "C:\\Users\\Jegan\\Downloads\\ffmpeg\\bin\\ffmpeg.exe -i \"" + loc + "\" -filter:v scale=\"640:trunc(ow/a/2)*2\" -b:v 128k -b:a 100k -r 20 \"" + dest_dir_name + filename + ".mp4\""
            tomp4(loc, dest_dir_name + "/" + os.path.splitext(os.path.basename(filename))[0] + ".mp4")
            print(loc)
            print(f'-------------------{i} / {totalfiles}----------------------')
            shutil.move(src=loc, dst=bin_dir_name)
            i = i + 1

from bs4 import BeautifulSoup
import urllib3
http = urllib3.PoolManager()
from bs4 import BeautifulSoup
import urllib3
import re

def downloadfile(url, path):
    import urllib3
    http = urllib3.PoolManager()
    r = http.request('GET', url, preload_content=False)

    with open(path, 'wb') as out:
        while True:
            data = r.read(1024 * 1024 * 30)
            if not data:
                break
            out.write(data)

    r.release_conn()


def downloadFromFTP(urls, convert, extension):
    for url in urls:
        response = http.request('GET', url)
        print(response)
        soup = BeautifulSoup(response.data)
        links = []
        import os
        i = 0
        t = True

        for link in soup.findAll('a', attrs={'href': re.compile(extension)}):
            i = i + 1
#             if '1-25.flv' == link.get('href'):
#                 t = True
            if i > 0 and link.get('href') not in links and t == True:
                links.append(link.get('href'))
                print(link.get('href'))
                downloadfile(url+link.get('href'), convert + os.path.basename( link.get('href')))


import os
import subprocess
import time
from os import listdir
import os
from os.path import isfile, join
import shutil



def concatenateFiles(dir_name, video_files_ffmpeg, extension, output_file, group=None):
    video_files = video_files_ffmpeg
    base_dir = dir_name

    files = []
    onlyfiles = [(join(dir_name, f), f) for f in listdir(dir_name) if isfile(join(dir_name, f))]
    onlyfiles.sort()
    for loc, filename in onlyfiles:
        if loc.endswith(extension):
            files.append(loc)
    files.sort()
    if group == None:
        group = len(files)
    i = 0
    tempfiles = []
    for f in files:
        tempfiles.append(f)
        i = i + 1

        if i % group == 0:
            file_list = open(video_files, "w")
            for tee in tempfiles:
                file_list.write("file '%s'\n" % tee)
            file_list.close()
            cmd = ["ffmpeg",
                   "-f",
                   "concat",
                   "-safe",
                   "0",
                   "-loglevel",
                   "quiet",
                   "-i",
                   "%s" % video_files,
                   "-c",
                   "copy",
                   "%s" % (output_file + str(i)+".mp4")
                   ]
            p = subprocess.Popen(cmd, stdin=subprocess.PIPE)
            fout = p.stdin
            fout.close()
            p.wait()
            print(p.returncode)
            tempfiles = []
    if len(tempfiles) > 0:
        file_list = open(video_files, "w")
        for tee in tempfiles:
            file_list.write("file '%s'\n" % tee)
        file_list.close()
        cmd = ["ffmpeg",
               "-f",
               "concat",
               "-safe",
               "0",
               "-loglevel",
               "quiet",
               "-i",
               "%s" % video_files,
               "-c",
               "copy",
               "%s" % (output_file + str(i)+".mp4")
               ]
        p = subprocess.Popen(cmd, stdin=subprocess.PIPE)
        fout = p.stdin
        fout.close()
        p.wait()
        print(p.returncode)
        tempfiles = []
        

import zipfile
from unrar import rarfile
import os
import subprocess
import time
from os import listdir
import os
from os.path import isfile, join
import shutil
import glob, os

def extractZip(dir_name, convert, delfol):
    loop = True
    while(loop == True):
        os.chdir(dir_name)
        unpacked = 0
        result = []
        for file in glob.glob("*.cbr"):
            result.append(dir_name + file)
        for file in glob.glob("*.cbz"):
            result.append(dir_name + file)
        for file in glob.glob("*.zip"):
            result.append(dir_name + file)
        for file in glob.glob("*.rar"):
            result.append(dir_name + file)


        import shutil

        for loc in result:
            shutil.move(src=loc, dst=convert)

        os.chdir(convert)
        result = []
        for file in glob.glob("**/*.cbr", recursive=True):
            result.append((convert +file, file[0:-4]))
        for file in glob.glob("**/*.cbz", recursive=True):
            result.append((convert + file, file[0:-4]))
        for file in glob.glob("**/*.rar", recursive=True):
            result.append((convert + file, file[0:-4]))
        for file in glob.glob("**/*.zip", recursive=True):
            result.append((convert + file, file[0:-4]))
        if len(result) == 0:
            loop = False
            
        for (filename, title) in result:
            os.system(f'mkdir "{convert+title}"')
            import subprocess
            params = f' x -o+ "{filename}" *.* "{convert+title}"'
            print(os.path.dirname(convert+title), "|", convert+title)
    #         try:
    #             rar = rarfile.RarFile(filename)
    #             rar.extractall(convert+title)

    #         except:
    #             rar = zipfile.ZipFile(filename)
    #             rar.extractall(convert+title)
            pyunpack.Archive(filename).extractall(convert+title)

            params = ''
            deleteplace = convert+"delete"
            shutil.move(src=filename, dst=delfol)
#             dir_name = "/Users/sjegan/Downloads/com2/"
            restucturedir(convert)

        print("done")
    restucturedir(convert)


def restructure(onlyfiles):
    for (subf, title) in onlyfiles:
#         print(subf)
        files = [(join(subf, f), f) for f in listdir(subf) if (not f.endswith('DS_Store')) and os.path.isfile(join(subf, f))]
        for (filename, title) in files:
            if "zzz" in title:
                os.remove(filename)
        folders = [(join(subf, f), f) for f in listdir(subf) if (not f.endswith('DS_Store')) and os.path.isdir(join(subf, f))]
        if len(files) == 0 and len(folders) == 0:
            shutil.rmtree(subf)
            continue
        if len(files) == 0 and len(folders) == 1:
#             print("YES")

            for (fold, title) in folders:
                subfiles = [(join(fold, f), f) for f in listdir(fold) if (not f.endswith('DS_Store'))]

#                 print(fold, "|",subf)
                for (subfile, titlesub) in subfiles:
                    shutil.move(src=subfile,dst=subf)
        onlyfiles = [(join(subf, f), f) for f in listdir(subf) if (not f.endswith('DS_Store')) and os.path.isdir(join(subf, f))]
        restructure(onlyfiles)

def restucturedir(dir_name):
    files = []
    folders = []
    onlyfiles = [(join(dir_name, f), f) for f in listdir(dir_name) if (not f.endswith('DS_Store')) and os.path.isdir(join(dir_name, f))]
    onlyfiles.sort()
    restructure(onlyfiles)

def extractNShrink(dir_name, convert, delfol, finaldir):
    extractZip(dir_name, convert, delfol)
    shrinkImages(convert)
    onlyfiles = [(join(convert, f), f) for f in listdir(convert) if (not f.endswith('DS_Store'))]
    for (f,t) in onlyfiles:
        shutil.move(src=f, dst=finaldir)


def numberingFiles(dir_name):
    files = []
    folders = []
    onlyfiles = [(join(dir_name, f), f) for f in listdir(dir_name) if (not f.endswith('DS_Store')) and os.path.isdir(join(dir_name, f))]
    onlyfiles.sort()

    for (subf, title) in onlyfiles:
    #         print(subf)
        files = [(join(subf, f), f) for f in listdir(subf) if (not f.endswith('DS_Store')) and os.path.isfile(join(subf, f))]
        folders = [(join(subf, f), f) for f in listdir(subf) if (not f.endswith('DS_Store')) and os.path.isdir(join(subf, f))]
        if len(folders) > 0:
            os.chdir(subf)
            result = []
            for file in glob.glob("**/*.jpg", recursive=True):
                result.append((subf + "/"+file, file))
            for file in glob.glob("**/*.jpeg", recursive=True):
                result.append((subf + "/"+ file, file))
            for file in glob.glob("**/*.JPG", recursive=True):
                result.append((subf + "/"+ file, file))
            for file in glob.glob("**/*.JPEG", recursive=True):
                result.append((subf + "/"+ file, file))
            for file in glob.glob("**/*.png", recursive=True):
                result.append((subf + "/"+ file, file))
            for file in glob.glob("**/*.PNG", recursive=True):
                result.append((subf + "/"+ file, file))
            result.sort()
            digits = 1 if len(result) < 10 else (2 if len(result) < 100 else (3 if len(result) < 1000 else 4))
            j = 1
            for (r, title) in result:
                dest = (f'{subf}/{str(j).zfill(digits)} {os.path.basename(title)}')
                shutil.move(src=r, dst=dest)
                j = j+1

        restucturedir(dir_name)
        restucturedir(dir_name)
        restucturedir(dir_name)

def makeZips(dirName):
    import shutil
    listOfFile = os.listdir(dirName)
    allFiles = list()
    for entry in listOfFile:
        fullPath = os.path.join(dirName, entry)
        if os.path.isdir(fullPath):
    #         print(fullPath)
            shutil.make_archive(fullPath, 'zip', fullPath)
            shutil.rmtree(fullPath)

# %%
dir_name = "/Users/sjegan/Downloads/com/"
convert = "/Users/sjegan/Downloads/com2/"
delfol = "/Users/sjegan/Downloads/del/"
finaldir = "/Users/sjegan/Downloads/uuu/"
extractNShrink(dir_name, convert, delfol, finaldir)
# numberingFiles(finaldir)
# Out:
# /Users/sjegan/Downloads/com2 | /Users/sjegan/Downloads/com2/Marvel Team-Up 001-010 (2004-2005) (digital) (Minutemen-Slayer)
# done
# /Users/sjegan/Downloads/com2/Marvel Team-Up 001-010 (2004-2005) (digital) (Minutemen-Slayer) | /Users/sjegan/Downloads/com2/Marvel Team-Up 001-010 (2004-2005) (digital) (Minutemen-Slayer)/Marvel Team-Up 010 (2005) (digital) (Minutemen-Slayer)
# /Users/sjegan/Downloads/com2/Marvel Team-Up 001-010 (2004-2005) (digital) (Minutemen-Slayer) | /Users/sjegan/Downloads/com2/Marvel Team-Up 001-010 (2004-2005) (digital) (Minutemen-Slayer)/Marvel Team-Up 003 (2005) (digital) (Minutemen-Slayer)
# /Users/sjegan/Downloads/com2/Marvel Team-Up 001-010 (2004-2005) (digital) (Minutemen-Slayer) | /Users/sjegan/Downloads/com2/Marvel Team-Up 001-010 (2004-2005) (digital) (Minutemen-Slayer)/Marvel Team-Up 002 (2005) (digital) (Minutemen-Slayer)
# /Users/sjegan/Downloads/com2/Marvel Team-Up 001-010 (2004-2005) (digital) (Minutemen-Slayer) | /Users/sjegan/Downloads/com2/Marvel Team-Up 001-010 (2004-2005) (digital) (Minutemen-Slayer)/Marvel Team-Up 008 (2005) (digital) (Minutemen-Slayer)
# /Users/sjegan/Downloads/com2/Marvel Team-Up 001-010 (2004-2005) (digital) (Minutemen-Slayer) | /Users/sjegan/Downloads/com2/Marvel Team-Up 001-010 (2004-2005) (digital) (Minutemen-Slayer)/Marvel Team-Up 006 (2005) (digital) (Minutemen-Slayer)
# /Users/sjegan/Downloads/com2/Marvel Team-Up 001-010 (2004-2005) (digital) (Minutemen-Slayer) | /Users/sjegan/Downloads/com2/Marvel Team-Up 001-010 (2004-2005) (digital) (Minutemen-Slayer)/Marvel Team-Up 009 (2005) (digital) (Minutemen-Slayer)
# /Users/sjegan/Downloads/com2/Marvel Team-Up 001-010 (2004-2005) (digital) (Minutemen-Slayer) | /Users/sjegan/Downloads/com2/Marvel Team-Up 001-010 (2004-2005) (digital) (Minutemen-Slayer)/Marvel Team-Up 001 (2004) (digital) (Minutemen-Slayer)
# /Users/sjegan/Downloads/com2/Marvel Team-Up 001-010 (2004-2005) (digital) (Minutemen-Slayer) | /Users/sjegan/Downloads/com2/Marvel Team-Up 001-010 (2004-2005) (digital) (Minutemen-Slayer)/Marvel Team-Up 007 (2005) (digital) (Minutemen-Slayer)
# /Users/sjegan/Downloads/com2/Marvel Team-Up 001-010 (2004-2005) (digital) (Minutemen-Slayer) | /Users/sjegan/Downloads/com2/Marvel Team-Up 001-010 (2004-2005) (digital) (Minutemen-Slayer)/Marvel Team-Up 005 (2005) (digital) (Minutemen-Slayer)
# /Users/sjegan/Downloads/com2/Marvel Team-Up 001-010 (2004-2005) (digital) (Minutemen-Slayer) | /Users/sjegan/Downloads/com2/Marvel Team-Up 001-010 (2004-2005) (digital) (Minutemen-Slayer)/Marvel Team-Up 004 (2005) (digital) (Minutemen-Slayer)
# done
# done

# %%
dir_name = "/Users/sjegan/Downloads/concat"

video_files_ffmpeg = "/Users/sjegan/Downloads/video_list.txt"
output_file = "/Users/sjegan/Downloads/House08"
extension = ".mp4"

concatenateFiles(dir_name, video_files_ffmpeg, extension, output_file, group=None)
# Out:
# 0
