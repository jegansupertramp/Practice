# %%
import pyunpack
from os import listdir
import os
from os.path import isfile, join
import shutil

from unrar import rarfile
import os
import subprocess
import time
from os import listdir
import os
from os.path import isfile, join
import shutil
import glob, os

def getDuration(filename, ppp=False):
    from pymediainfo import MediaInfo
    media_info = MediaInfo.parse(filename)
    #duration in milliseconds
    duration_in_ms = media_info.tracks[0].duration
    if ppp is True:
        print(f'FileDuration --- {filename} = {(round(duration_in_ms/(1000*60)))}')
    return (round(duration_in_ms/(1000*60)))

def getDurationDir(dir_name):
    onlyfiles = [(join(dir_name, f), f) for f in listdir(dir_name) if isfile(join(dir_name, f))]
    totalfiles = len(onlyfiles)
    onlyfiles.sort()
    i=1
    onlyfiles.sort
    dur = 0
    for loc, filename in onlyfiles:
        if loc.endswith(".avi") or loc.endswith(".mp4") or loc.endswith(".MP4") or loc.endswith(".mkv") or loc.endswith(".mpg") or loc.endswith(".flv"):
            dur += getDuration(loc)
    print(f"Directory in Minutes = {dur}")
    return dur

def convertByPIL(source, destination, small=False):
    from PIL import Image
    image = Image.open(source)
    w1 = image.width
    h1 = image.height
    h2 = 1024
    if(small == True):
        h2 = 512
    w2 = int((w1*h2)/h1)
    newImage = image.resize((w2, h2), Image.NEAREST)
    os.remove(source)
    newImage.save(destination)

def convertByScipy(source, destination, small=False):
    import scipy.misc
    import numpy as np
    img = scipy.misc.imread(imgpath)
    assert len(img.shape) == 3
    w1 = img.shape[0]
    h1 = img.shape[1]
    h2 = 1024
    w2 = int((w1*h2)/h1)

    if small == True:
        if w2 > h2:
            h2 = 512
            w2 = int((w1*h2)/h1)
    img_resized = scipy.misc.imresize(img, (w2, h2))
    img_answer = (img_resized/255.0).astype('float32')

    import matplotlib.pyplot as plt
#     plt.imshow(np.uint8(img))
#     plt.show()
#     plt.imshow(np.uint8(img_resized))
#     plt.show()
    os.remove(source)
    scipy.misc.imsave(destination, img_resized)

def convertImage(source, destination, small=False, delfol = "/Users/sjegan/Downloads/del/"):
    import scipy
    imgpath = source
    try:
        convertByScipy(source, destination, small)
    except:
        try:
            convertByPIL(source, destination, small)
        except:
            print(f'Error in Conversion - {source}')
            shutil.move(src=source, dst=delfol)

def convertAllImages(files, small=False):
    for f in files:
        convertImage(f, f'{f[0:-4]}.jpg', small)

def getListOfFiles(dirName, filterlist):
    listOfFile = os.listdir(dirName)
    allFiles = list()
    for entry in listOfFile:
        fullPath = os.path.join(dirName, entry)
        if os.path.isdir(fullPath):
            allFiles = allFiles + getListOfFiles(fullPath, filterlist)
        else:
            canadd = False
            for f in filterlist:
                if fullPath.endswith(f):
                    allFiles.append(fullPath)
                    break
    allFiles.sort()
                
    return allFiles
def shrinkImages(dir_name):
    from webptools import webplib as webp
    webpFiles = getListOfFiles(dir_name, ['webp'])
    for (w) in webpFiles:
#         webp.dwebp(w,f'{w}.jpg',"-o")
        os.system(f'dwebp "{w}" -o "{w}.jpg"')
        os.remove(w)
    files = getListOfFiles(dir_name, ['jpg', 'jpeg', 'JPEG', 'JPG', 'png', 'PNG'])
    convertAllImages(files, False)

def tomp4(input_file, output_file):
    import time
    getDuration(input_file, True)
    start_time = time.time()
    import ffmpy
    crf = 18
    input_name = input_file
    output_name = output_file
    inp={input_name:None}
    outp = {output_name:'-vcodec libx264 -crf 28 -preset faster -tune film -strict -2 -filter:v scale="640:trunc(ow/a/2)*2" -b:v 128k -b:a 100k -r 20 '}
    outp = {output_name:'-af apad -shortest -avoid_negative_ts make_zero -fflags +genpts -vcodec libx264 -acodec aac -preset faster -tune film -strict -2 -filter:v scale="640:trunc(ow/a/2)*2" -b:v 128k -b:a 100k -r 20 -map 0:v:0 -map 0:a:0 '}
    ff=ffmpy.FFmpeg(inputs=inp,outputs=outp)
    print(ff.cmd) # just to verify that it produces the correct ffmpeg command
    ff.run()
    print(f"---- {output_file} --- {(time.time() - start_time)} seconds ---")
    return (time.time() - start_time)

def tomp4audiovideo(input_file, output_file, audio=0, video=0):
    import time
    getDuration(input_file, True)
    start_time = time.time()
    import ffmpy
    crf = 18
    input_name = input_file
    output_name = output_file
    inp={input_name:None}
    outp = {output_name:'-vcodec libx264 -crf 28 -preset faster -tune film -strict -2 -filter:v scale="640:trunc(ow/a/2)*2" -b:v 128k -b:a 100k -r 20 '}
    outp = {output_name:'-af apad -shortest -avoid_negative_ts make_zero -fflags +genpts -vcodec libx264 -acodec aac -preset faster -tune film -strict -2 -filter:v scale="640:trunc(ow/a/2)*2" -b:v 128k -b:a 100k -r 20 -map 0:a:1 '}
    outp = {output_name:' -map 0:v:0 -map 0:a:1 '}
    ff=ffmpy.FFmpeg(inputs=inp,outputs=outp)
    print(ff.cmd) # just to verify that it produces the correct ffmpeg command
    ff.run()
    print(f"---- {output_file} --- {(time.time() - start_time)} seconds ---")

def chooseAudioVideo(dir_name, dest_dir_name, bin_dir_name, audio=0, video=0):
    onlyfiles = [(join(dir_name, f), f) for f in listdir(dir_name) if isfile(join(dir_name, f))]
    totalfiles = len(onlyfiles)
    onlyfiles.sort()
    i=1
    onlyfiles.sort
    totalminutes = getDurationDir(dir_name)
    for loc, filename in onlyfiles:
        if loc.endswith(".avi") or loc.endswith(".mp4") or loc.endswith(".MP4") or loc.endswith(".mkv") or loc.endswith(".mpg") or loc.endswith(".flv"):
#             print(loc)
            import datetime
            print(f'-------------------{i} / {totalfiles}----------------------')
#             2 minutes for 23 minutes
#             1 minute for 12 minutes
            import time
            
            print(f'--- Estimate {time.ctime(time.time() + round(totalminutes * 15))}')
            cmd_filelist = "C:\\Users\\Jegan\\Downloads\\ffmpeg\\bin\\ffmpeg.exe -i \"" + loc + "\" -filter:v scale=\"640:trunc(ow/a/2)*2\" -b:v 128k -b:a -bsf:v h264_mp4toannexb 100k -r 20 \"" + dest_dir_name + filename + ".mp4\""
            try:
                dur = getDuration(loc)
                tomp4audiovideo(loc, dest_dir_name + "/" + os.path.splitext(os.path.basename(filename))[0] + ".mp4", audio, video)
                shutil.move(src=loc, dst=bin_dir_name)
                totalminutes -= dur
            except:
                print("*****************FAILED***************" + loc)
            i = i + 1

def tosmmp4(input_file, output_file):
    import ffmpy
    crf = 18
    input_name = input_file
    output_name = output_file
    inp={input_name:None}
    outp = {output_name:'-vcodec libx264 -crf 28 -preset faster -tune film -strict -2 -filter:v scale="640:trunc(ow/a/2)*2" -b:v 128k -b:a 100k -r 20 '}
    outp = {output_name:'-af apad -shortest -avoid_negative_ts make_zero -fflags +genpts -vcodec libx264 -acodec aac -preset faster -tune film -strict -2 -filter:v scale="360:trunc(ow/a/2)*2" -b:v 50k -b:a 30k -r 20 '}
    ff=ffmpy.FFmpeg(inputs=inp,outputs=outp)
#     print(ff.cmd) # just to verify that it produces the correct ffmpeg command
    ff.run()
def shrinkTinyVideos(dir_name, dest_dir_name, bin_dir_name):
    onlyfiles = [(join(dir_name, f), f) for f in listdir(dir_name) if isfile(join(dir_name, f))]
    totalfiles = len(onlyfiles)
    onlyfiles.sort()
    i=1
    onlyfiles.sort
    for loc, filename in onlyfiles:
        if loc.endswith(".avi") or loc.endswith(".mp4") or loc.endswith(".MP4") or loc.endswith(".mkv") or loc.endswith(".mpg") or loc.endswith(".flv"):
            cmd_filelist = "C:\\Users\\Jegan\\Downloads\\ffmpeg\\bin\\ffmpeg.exe -i \"" + loc + "\" -filter:v scale=\"640:trunc(ow/a/2)*2\" -b:v 128k -b:a 100k -r 20 \"" + dest_dir_name + filename + ".mp4\""
            try:
                tosmmp4(loc, dest_dir_name + "/" + os.path.splitext(os.path.basename(filename))[0] + ".mp4")
                print(loc)
                print(f'-------------------{i} / {totalfiles}----------------------')
                shutil.move(src=loc, dst=bin_dir_name)
            except:
                print("*****************FAILED***************" + loc)
            i = i + 1
from os import listdir
import os
import ffmpy
from os.path import isfile, join
import shutil

def shrinkVideos(dir_name, dest_dir_name, bin_dir_name):
    onlyfiles = [(join(dir_name, f), f) for f in listdir(dir_name) if isfile(join(dir_name, f))]
    totalfiles = len(onlyfiles)
    onlyfiles.sort()
    i=1
    onlyfiles.sort
    minutestime = []
    totalminutes = getDurationDir(dir_name)
    for loc, filename in onlyfiles:
        if loc.endswith(".avi") or loc.endswith(".mp4") or loc.endswith(".MP4") or loc.endswith(".mkv") or loc.endswith(".mpg") or loc.endswith(".flv"):
#             print(loc)
            import datetime
            print(f'-------------------{i} / {totalfiles}----------------------')
#             2 minutes for 23 minutes
#             1 minute for 12 minutes
            import time
            
            print(f'--- Estimate {time.ctime(time.time() + round(totalminutes * 15))}')
            cmd_filelist = "C:\\Users\\Jegan\\Downloads\\ffmpeg\\bin\\ffmpeg.exe -i \"" + loc + "\" -filter:v scale=\"640:trunc(ow/a/2)*2\" -b:v 128k -b:a -bsf:v h264_mp4toannexb 100k -r 20 \"" + dest_dir_name + filename + ".mp4\""
            try:
                dur = getDuration(loc)
                timetaken = tomp4(loc, dest_dir_name + "/" + os.path.splitext(os.path.basename(filename))[0] + ".mp4")
                minutestime.append((dur, totalminutes))
                shutil.move(src=loc, dst=bin_dir_name)
                totalminutes -= dur
                
            except:
                print("*****************FAILED***************" + loc)
            i = i + 1
#             break
    return minutestime

from bs4 import BeautifulSoup
import urllib3
http = urllib3.PoolManager()
from bs4 import BeautifulSoup
import urllib3
import re

def downloadfile(url, path):
    import urllib3
    http = urllib3.PoolManager()
    r = http.request('GET', url, preload_content=False)

    with open(path, 'wb') as out:
        while True:
            data = r.read(1024 * 1024 * 30)
            if not data:
                break
            out.write(data)

    r.release_conn()


def downloadFromFTP(urls, convert, extension):
    for url in urls:
        response = http.request('GET', url)
        print(response)
        soup = BeautifulSoup(response.data)
        links = []
        import os
        i = 0
        t = True

        for link in soup.findAll('a', attrs={'href': re.compile(extension)}):
            i = i + 1
#             if '1-25.flv' == link.get('href'):
#                 t = True
            if i > 10 and link.get('href') not in links and t == True:
                links.append(link.get('href'))
                print(link.get('href'))
                downloadfile(url+link.get('href'), convert + os.path.basename( link.get('href')))


import os
import subprocess
import time
from os import listdir
import os
from os.path import isfile, join
import shutil

def removeHyphen(dir_name):
    import shutil
    from os import listdir
    video_files = video_files_ffmpeg
    base_dir = dir_name

    files = []
    onlyfiles = [(join(dir_name, f), f) for f in listdir(dir_name) if isfile(join(dir_name, f))]
    onlyfiles.sort()
    for loc, filename in onlyfiles:
        if loc.endswith(extension):
            files.append(loc)
    for f in files:
        if f.find("\'") != -1:
            r = f.replace("\'", "")
            shutil.move(src=f, dst=r)

def concatenateFiles(dir_name, video_files_ffmpeg, extension, output_file, group=None):
    removeHyphen(dir_name)
    
    import time
    totalminutes = getDurationDir(dir_name)
    print(f'--- Estimate {time.ctime(time.time() + round(totalminutes * 254 / 851))}')
    start_time = time.time()
    
    video_files = video_files_ffmpeg
    base_dir = dir_name

    files = []
    onlyfiles = [(join(dir_name, f), f) for f in listdir(dir_name) if isfile(join(dir_name, f))]
    onlyfiles.sort()
    for loc, filename in onlyfiles:
        if loc.endswith(extension):
            files.append(loc)
    files.sort()
    if group == None:
        group = len(files)
    i = 0
    tempfiles = []
    for f in files:
        tempfiles.append(f)
        i = i + 1

        if i % group == 0:
            file_list = open(video_files, "w")
            for tee in tempfiles:
                file_list.write("file '%s'\n" % tee)
            file_list.close()
            cmd = ["ffmpeg",
                   "-f",
                   "concat",
                   "-safe",
                   "0",
                   "-async",
                   "1",
                   "-loglevel",
                   "quiet",
                   "-i",
                   "%s" % video_files,
                   "-c",
                   "copy",
                   "%s" % (output_file + str(i)+".mp4")
                   
                   ]
            p = subprocess.Popen(cmd, stdin=subprocess.PIPE)
            fout = p.stdin
            fout.close()
            p.wait()
            print(p.returncode)
            tempfiles = []
    if len(tempfiles) > 0:
        file_list = open(video_files, "w")
        for tee in tempfiles:
            file_list.write("file '%s'\n" % tee)
        file_list.close()
        cmd = ["ffmpeg",
               "-f",
               "concat",
               "-safe",
               "0",
               "-loglevel",
               "quiet",
               "-i",
               "%s" % video_files,
               "-c",
               "copy",
               "%s" % (output_file + str(i)+".mp4")
               ]
        p = subprocess.Popen(cmd, stdin=subprocess.PIPE)
        fout = p.stdin
        fout.close()
        p.wait()
        print(p.returncode)
        tempfiles = []
    
    print(f"---- {output_file} --- {(time.time() - start_time)} seconds ---")
    return (time.time() - start_time)
        

import zipfile
from unrar import rarfile
import os
import subprocess
import time
from os import listdir
import os
from os.path import isfile, join
import shutil
import glob, os

def extractZip(dir_name, convert, delfol):
    loop = True
    kkk = 0
    while(loop == True):
        os.chdir(dir_name)
        unpacked = 0
        result = []
        for file in glob.glob("*.cbr"):
            result.append(dir_name + file)
        for file in glob.glob("*.cbz"):
            result.append(dir_name + file)
        for file in glob.glob("*.zip"):
            result.append(dir_name + file)
        for file in glob.glob("*.rar"):
            result.append(dir_name + file)


        import shutil

        for loc in result:
            shutil.move(src=loc, dst=convert)

        os.chdir(convert)
        result = []
        for file in glob.glob("**/*.cbr", recursive=True):
            result.append((convert +file, file[0:-4]))
        for file in glob.glob("**/*.cbz", recursive=True):
            result.append((convert + file, file[0:-4]))
        for file in glob.glob("**/*.rar", recursive=True):
            result.append((convert + file, file[0:-4]))
        for file in glob.glob("**/*.zip", recursive=True):
            result.append((convert + file, file[0:-4]))
        if len(result) == 0:
            loop = False
            
        for (filename, title) in result:
            os.system(f'mkdir "{convert+title}"')
            import subprocess
            params = f' x -o+ "{filename}" *.* "{convert+title}"'
            print(os.path.dirname(convert+title), "|", convert+title)
    #         try:
    #             rar = rarfile.RarFile(filename)
    #             rar.extractall(convert+title)

    #         except:
    #             rar = zipfile.ZipFile(filename)
    #             rar.extractall(convert+title)
            pyunpack.Archive(filename).extractall(convert+title)

            params = ''
            deleteplace = convert+"delete"
            shutil.move(src=filename, dst=delfol+"/"+os.path.basename(filename)+str(kkk))
            kkk = kkk + 1
#             dir_name = "/Users/sjegan/Downloads/com2/"
            restucturedir(convert)

        print("done")
    restucturedir(convert)


def restructure(onlyfiles):
    for (subf, title) in onlyfiles:
#         print(subf)
        files = [(join(subf, f), f) for f in listdir(subf) if (not f.endswith('DS_Store')) and os.path.isfile(join(subf, f))]
        for (filename, title) in files:
            if "zzz" in title:
                os.remove(filename)
        folders = [(join(subf, f), f) for f in listdir(subf) if (not f.endswith('DS_Store')) and os.path.isdir(join(subf, f))]
        if len(files) == 0 and len(folders) == 0:
            shutil.rmtree(subf)
            continue
        if len(files) == 0 and len(folders) == 1:
#             print("YES")

            for (fold, title) in folders:
                subfiles = [(join(fold, f), f) for f in listdir(fold) if (not f.endswith('DS_Store'))]

#                 print(fold, "|",subf)
                for (subfile, titlesub) in subfiles:
                    shutil.move(src=subfile,dst=subf)
        onlyfiles = [(join(subf, f), f) for f in listdir(subf) if (not f.endswith('DS_Store')) and os.path.isdir(join(subf, f))]
        restructure(onlyfiles)

def restucturedir(dir_name):
    files = []
    folders = []
    onlyfiles = [(join(dir_name, f), f) for f in listdir(dir_name) if (not f.endswith('DS_Store')) and os.path.isdir(join(dir_name, f))]
    onlyfiles.sort()
    restructure(onlyfiles)

def extractNShrink(dir_name, convert, delfol, finaldir):
    extractZip(dir_name, convert, delfol)
    shrinkImages(convert)
    onlyfiles = [(join(convert, f), f) for f in listdir(convert) if (not f.endswith('DS_Store'))]
    for (f,t) in onlyfiles:
        shutil.move(src=f, dst=finaldir)


def numberingFiles(dir_name):
    files = []
    folders = []
    onlyfiles = [(join(dir_name, f), f) for f in listdir(dir_name) if (not f.endswith('DS_Store')) and os.path.isdir(join(dir_name, f))]
    onlyfiles.sort()

    for (subf, title) in onlyfiles:
    #         print(subf)
        files = [(join(subf, f), f) for f in listdir(subf) if (not f.endswith('DS_Store')) and os.path.isfile(join(subf, f))]
        folders = [(join(subf, f), f) for f in listdir(subf) if (not f.endswith('DS_Store')) and os.path.isdir(join(subf, f))]
        if len(folders) > 0:
            os.chdir(subf)
            result = []
            for file in glob.glob("**/*.jpg", recursive=True):
                result.append((subf + "/"+file, file))
            for file in glob.glob("**/*.jpeg", recursive=True):
                result.append((subf + "/"+ file, file))
            for file in glob.glob("**/*.JPG", recursive=True):
                result.append((subf + "/"+ file, file))
            for file in glob.glob("**/*.JPEG", recursive=True):
                result.append((subf + "/"+ file, file))
            for file in glob.glob("**/*.png", recursive=True):
                result.append((subf + "/"+ file, file))
            for file in glob.glob("**/*.PNG", recursive=True):
                result.append((subf + "/"+ file, file))
            result.sort()
            digits = 1 if len(result) < 10 else (2 if len(result) < 100 else (3 if len(result) < 1000 else 4))
            j = 1
            for (r, title) in result:
                dest = (f'{subf}/{str(j).zfill(digits)} {os.path.basename(title)}')
                shutil.move(src=r, dst=dest)
                j = j+1

        restucturedir(dir_name)
        restucturedir(dir_name)
        restucturedir(dir_name)

def makeZips(dirName):
    import shutil
    listOfFile = os.listdir(dirName)
    allFiles = list()
    for entry in listOfFile:
        fullPath = os.path.join(dirName, entry)
        if os.path.isdir(fullPath):
    #         print(fullPath)
            shutil.make_archive(fullPath, 'zip', fullPath)
            shutil.rmtree(fullPath)

def renameNRestructure(dir_name):
    files = []
    folders = []
    onlyfiles = [(join(dir_name, f), f) for f in listdir(dir_name) if (not f.endswith('DS_Store')) and os.path.isdir(join(dir_name, f))]
    onlyfiles.sort()

    for (subf, title) in onlyfiles:
    #         print(subf)
#         print(title)
        title2 = title
        files = [(join(subf, f), f) for f in listdir(subf) if (not f.endswith('DS_Store')) and os.path.isfile(join(subf, f))]
        folders = [(join(subf, f), f) for f in listdir(subf) if (not f.endswith('DS_Store')) and os.path.isdir(join(subf, f))]
        if len(folders) > 0:
            os.chdir(subf)
            result = []
            for file in glob.glob("**/*.jpg", recursive=True):
                result.append((subf + "/"+file, file))
            for file in glob.glob("**/*.jpeg", recursive=True):
                result.append((subf + "/"+ file, file))
            for file in glob.glob("**/*.JPG", recursive=True):
                result.append((subf + "/"+ file, file))
            for file in glob.glob("**/*.JPEG", recursive=True):
                result.append((subf + "/"+ file, file))
            for file in glob.glob("**/*.png", recursive=True):
                result.append((subf + "/"+ file, file))
            for file in glob.glob("**/*.PNG", recursive=True):
                result.append((subf + "/"+ file, file))
            result.sort()
            digits = 1 if len(result) < 10 else (2 if len(result) < 100 else (3 if len(result) < 1000 else 4))
            j = 1
            for (r, title) in result:
                dest = (f'{subf}/{title2}{str(j).zfill(digits)} {os.path.basename(title)}')
    #             print(dest)
    #             break
                shutil.move(src=r, dst=dest)
                j = j+1

        restucturedir(dir_name)
        restucturedir(dir_name)
        restucturedir(dir_name)
        
def removeTxt(dir_name):
    files = []
    folders = []
    onlyfiles = [(join(dir_name, f), f) for f in listdir(dir_name) if (not f.endswith('DS_Store')) and os.path.isdir(join(dir_name, f))]
    onlyfiles.sort()

    for (subf, title) in onlyfiles:
    #         print(subf)
#         print(title)
        title2 = title
        files = [(join(subf, f), f) for f in listdir(subf) if (not f.endswith('DS_Store')) and os.path.isfile(join(subf, f))]
        folders = [(join(subf, f), f) for f in listdir(subf) if (not f.endswith('DS_Store')) and os.path.isdir(join(subf, f))]
        if len(folders) > 0:
            os.chdir(subf)
            result = []
            for file in glob.glob("**/*.txt", recursive=True):
                result.append((subf + "/"+file, file))
            result.sort()
            for (r, title) in result:
                os.remove(r)

        restucturedir(dir_name)
        restucturedir(dir_name)
        restucturedir(dir_name)

# %%
dir_name = "/Users/sjegan/Downloads/com2/"
dest_dir_name = "/Users/sjegan/Downloads/dest/"
bin_dir_name = "/Users/sjegan/Downloads/dest/del"
minutestime = shrinkVideos(dir_name, dest_dir_name, bin_dir_name)
# Out:
# Directory in Minutes = 355
# -------------------1 / 7----------------------
# --- Estimate Thu Jan  9 20:26:40 2020
# FileDuration --- /Users/sjegan/Downloads/com2/The.Wire.S04E12.720p.BluRay.nHD.x264-NhaNc3.mp4 = 59
# ffmpeg -i /Users/sjegan/Downloads/com2/The.Wire.S04E12.720p.BluRay.nHD.x264-NhaNc3.mp4 -af apad -shortest -avoid_negative_ts make_zero -fflags +genpts -vcodec libx264 -acodec aac -preset faster -tune film -strict -2 -filter:v scale=640:trunc(ow/a/2)*2 -b:v 128k -b:a 100k -r 20 -map 0:v:0 -map 0:a:0 /Users/sjegan/Downloads/dest//The.Wire.S04E12.720p.BluRay.nHD.x264-NhaNc3.mp4
# ---- /Users/sjegan/Downloads/dest//The.Wire.S04E12.720p.BluRay.nHD.x264-NhaNc3.mp4 --- 891.6943891048431 seconds ---
# -------------------2 / 7----------------------
# --- Estimate Thu Jan  9 20:26:47 2020
# FileDuration --- /Users/sjegan/Downloads/com2/The.Wire.S05E01.720p.BluRay.nHD.x264-NhaNc3.mp4 = 59
# ffmpeg -i /Users/sjegan/Downloads/com2/The.Wire.S05E01.720p.BluRay.nHD.x264-NhaNc3.mp4 -af apad -shortest -avoid_negative_ts make_zero -fflags +genpts -vcodec libx264 -acodec aac -preset faster -tune film -strict -2 -filter:v scale=640:trunc(ow/a/2)*2 -b:v 128k -b:a 100k -r 20 -map 0:v:0 -map 0:a:0 /Users/sjegan/Downloads/dest//The.Wire.S05E01.720p.BluRay.nHD.x264-NhaNc3.mp4
# ---- /Users/sjegan/Downloads/dest//The.Wire.S05E01.720p.BluRay.nHD.x264-NhaNc3.mp4 --- 849.5339388847351 seconds ---
# -------------------3 / 7----------------------
# --- Estimate Thu Jan  9 20:26:12 2020
# FileDuration --- /Users/sjegan/Downloads/com2/The.Wire.S05E02.720p.BluRay.nHD.x264-NhaNc3.mp4 = 59
# ffmpeg -i /Users/sjegan/Downloads/com2/The.Wire.S05E02.720p.BluRay.nHD.x264-NhaNc3.mp4 -af apad -shortest -avoid_negative_ts make_zero -fflags +genpts -vcodec libx264 -acodec aac -preset faster -tune film -strict -2 -filter:v scale=640:trunc(ow/a/2)*2 -b:v 128k -b:a 100k -r 20 -map 0:v:0 -map 0:a:0 /Users/sjegan/Downloads/dest//The.Wire.S05E02.720p.BluRay.nHD.x264-NhaNc3.mp4
# ---- /Users/sjegan/Downloads/dest//The.Wire.S05E02.720p.BluRay.nHD.x264-NhaNc3.mp4 --- 747.8913021087646 seconds ---
# -------------------4 / 7----------------------
# --- Estimate Thu Jan  9 20:23:55 2020
# FileDuration --- /Users/sjegan/Downloads/com2/The.Wire.S05E04.720p.BluRay.nHD.x264-NhaNc3.mp4 = 59
# ffmpeg -i /Users/sjegan/Downloads/com2/The.Wire.S05E04.720p.BluRay.nHD.x264-NhaNc3.mp4 -af apad -shortest -avoid_negative_ts make_zero -fflags +genpts -vcodec libx264 -acodec aac -preset faster -tune film -strict -2 -filter:v scale=640:trunc(ow/a/2)*2 -b:v 128k -b:a 100k -r 20 -map 0:v:0 -map 0:a:0 /Users/sjegan/Downloads/dest//The.Wire.S05E04.720p.BluRay.nHD.x264-NhaNc3.mp4
# ---- /Users/sjegan/Downloads/dest//The.Wire.S05E04.720p.BluRay.nHD.x264-NhaNc3.mp4 --- 888.7799978256226 seconds ---
# -------------------5 / 7----------------------
# --- Estimate Thu Jan  9 20:23:59 2020
# FileDuration --- /Users/sjegan/Downloads/com2/The.Wire.S05E08.720p.BluRay.nHD.x264-NhaNc3.mp4 = 59
# ffmpeg -i /Users/sjegan/Downloads/com2/The.Wire.S05E08.720p.BluRay.nHD.x264-NhaNc3.mp4 -af apad -shortest -avoid_negative_ts make_zero -fflags +genpts -vcodec libx264 -acodec aac -preset faster -tune film -strict -2 -filter:v scale=640:trunc(ow/a/2)*2 -b:v 128k -b:a 100k -r 20 -map 0:v:0 -map 0:a:0 /Users/sjegan/Downloads/dest//The.Wire.S05E08.720p.BluRay.nHD.x264-NhaNc3.mp4
# ---- /Users/sjegan/Downloads/dest//The.Wire.S05E08.720p.BluRay.nHD.x264-NhaNc3.mp4 --- 817.9139420986176 seconds ---
# -------------------6 / 7----------------------
# --- Estimate Thu Jan  9 20:22:53 2020
# FileDuration --- /Users/sjegan/Downloads/com2/The.Wire.S05E09.720p.BluRay.nHD.x264-NhaNc3.mp4 = 60
# ffmpeg -i /Users/sjegan/Downloads/com2/The.Wire.S05E09.720p.BluRay.nHD.x264-NhaNc3.mp4 -af apad -shortest -avoid_negative_ts make_zero -fflags +genpts -vcodec libx264 -acodec aac -preset faster -tune film -strict -2 -filter:v scale=640:trunc(ow/a/2)*2 -b:v 128k -b:a 100k -r 20 -map 0:v:0 -map 0:a:0 /Users/sjegan/Downloads/dest//The.Wire.S05E09.720p.BluRay.nHD.x264-NhaNc3.mp4
# ---- /Users/sjegan/Downloads/dest//The.Wire.S05E09.720p.BluRay.nHD.x264-NhaNc3.mp4 --- 768.0974318981171 seconds ---

# %%
dir_name = "/Users/sjegan/Downloads/concat"

video_files_ffmpeg = "/Users/sjegan/Downloads/video_list.txt"
output_file = "/Users/sjegan/Downloads/BBB"
extension = ".mp4"

concatenateFiles(dir_name, video_files_ffmpeg, extension, output_file, group=None)
# Out:
# Directory in Minutes = 933
# --- Estimate Fri Jan 10 02:56:18 2020
# 0
# ---- /Users/sjegan/Downloads/BBB --- 102.62986993789673 seconds ---
# 102.63005781173706

# %%
254/851
# Out:
# 0.2984723854289072

# %%
def downloadFromFTP2(urls, convert, extension):
    for url in urls:
        response = http.request('GET', url)
        print(response)
        soup = BeautifulSoup(response.data)
        links = []
        import os
        i = 0
        t = True

        for link in soup.findAll('a', attrs={'href': re.compile(extension)}):
            i = i + 1
#             if '1-25.flv' == link.get('href'):
#                 t = True
            if i > 10 and link.get('href') not in links and t == True:
                links.append(link.get('href'))
                print('http://94.130.23.244/'+link.get('href'))
                if("the.shield.s01e11.1080p.bluray.x264-rovers.mp4" == os.path.basename( link.get('href'))):
                    continue
#                 downloadfile(url+link.get('href'), convert + os.path.basename( link.get('href')))
                import urllib.request
                try:
                    urllib.request.urlretrieve(url+link.get('href'), convert + os.path.basename( link.get('href')))
                except:
                    try:
                        urllib.request.urlretrieve(url+link.get('href'), convert + os.path.basename( link.get('href'))) 
                    except:
                        try:
                            urllib.request.urlretrieve(url+link.get('href'), convert + os.path.basename( link.get('href'))) 
                        except:
                            continue

#                   downloadfile('http://94.130.23.244/'+link.get('href'), convert + os.path.basename( link.get('href')))
                
                dir_name = "/Users/sjegan/Downloads/DownloadStar"
                dest_dir_name = "/Users/sjegan/Downloads/dest"
                bin_dir_name = "/Users/sjegan/Downloads/dest/del"
                shrinkVideos(dir_name, dest_dir_name, bin_dir_name)
                
urls = [
#         'http://dl.sitemovie.ir/serial/prison%20break/s2/',
#         'http://dl.sitemovie.ir/serial/prison%20break/s3/', 
#         'http://dl.sitemovie.ir/serial/prison%20break/s4/', 
        'http://94.130.23.244/TV%20Shows%20A/Grimm/Season%201/',
        'http://94.130.23.244/TV%20Shows%20A/Grimm/Season%202/',
        'http://94.130.23.244/TV%20Shows%20A/Grimm/Season%203/',
        'http://94.130.23.244/TV%20Shows%20A/Grimm/Season%204/',
        'http://94.130.23.244/TV%20Shows%20A/Grimm/Season%205/',
        'http://94.130.23.244/TV%20Shows%20A/Grimm/Season%206/',
        
        ]
convert = "/Users/sjegan/Downloads/DownloadStar/"
extension = "mp4"
downloadFromFTP2(urls, convert, extension)
# Out:
# <urllib3.response.HTTPResponse object at 0x1069bbba8>
# http://94.130.23.244/Grimm.S01E11.720p.BluRay.X264-CLUE.mp4
# Directory in Minutes = 43
# -------------------1 / 2----------------------
# --- Estimate Fri Jan 10 04:43:25 2020
# FileDuration --- /Users/sjegan/Downloads/DownloadStar/Grimm.S01E11.720p.BluRay.X264-CLUE.mp4 = 43
# ffmpeg -i /Users/sjegan/Downloads/DownloadStar/Grimm.S01E11.720p.BluRay.X264-CLUE.mp4 -af apad -shortest -avoid_negative_ts make_zero -fflags +genpts -vcodec libx264 -acodec aac -preset faster -tune film -strict -2 -filter:v scale=640:trunc(ow/a/2)*2 -b:v 128k -b:a 100k -r 20 -map 0:v:0 -map 0:a:0 /Users/sjegan/Downloads/dest/Grimm.S01E11.720p.BluRay.X264-CLUE.mp4
# ---- /Users/sjegan/Downloads/dest/Grimm.S01E11.720p.BluRay.X264-CLUE.mp4 --- 1125.2780449390411 seconds ---
# http://94.130.23.244/Grimm.S01E12.720p.BluRay.X264-CLUE.mp4
# Directory in Minutes = 43
# -------------------1 / 2----------------------
# --- Estimate Fri Jan 10 05:04:40 2020
# FileDuration --- /Users/sjegan/Downloads/DownloadStar/Grimm.S01E12.720p.BluRay.X264-CLUE.mp4 = 43
# ffmpeg -i /Users/sjegan/Downloads/DownloadStar/Grimm.S01E12.720p.BluRay.X264-CLUE.mp4 -af apad -shortest -avoid_negative_ts make_zero -fflags +genpts -vcodec libx264 -acodec aac -preset faster -tune film -strict -2 -filter:v scale=640:trunc(ow/a/2)*2 -b:v 128k -b:a 100k -r 20 -map 0:v:0 -map 0:a:0 /Users/sjegan/Downloads/dest/Grimm.S01E12.720p.BluRay.X264-CLUE.mp4
# ---- /Users/sjegan/Downloads/dest/Grimm.S01E12.720p.BluRay.X264-CLUE.mp4 --- 1014.2151210308075 seconds ---
# http://94.130.23.244/Grimm.S01E13.720p.BluRay.X264-CLUE.mp4
# Directory in Minutes = 43
# -------------------1 / 2----------------------
# --- Estimate Fri Jan 10 05:23:25 2020
# FileDuration --- /Users/sjegan/Downloads/DownloadStar/Grimm.S01E13.720p.BluRay.X264-CLUE.mp4 = 43
# ffmpeg -i /Users/sjegan/Downloads/DownloadStar/Grimm.S01E13.720p.BluRay.X264-CLUE.mp4 -af apad -shortest -avoid_negative_ts make_zero -fflags +genpts -vcodec libx264 -acodec aac -preset faster -tune film -strict -2 -filter:v scale=640:trunc(ow/a/2)*2 -b:v 128k -b:a 100k -r 20 -map 0:v:0 -map 0:a:0 /Users/sjegan/Downloads/dest/Grimm.S01E13.720p.BluRay.X264-CLUE.mp4
# ---- /Users/sjegan/Downloads/dest/Grimm.S01E13.720p.BluRay.X264-CLUE.mp4 --- 768.3128142356873 seconds ---
# http://94.130.23.244/Grimm.S01E14.720p.BluRay.X264-CLUE.mp4
# http://94.130.23.244/Grimm.S01E15.720p.BluRay.X264-CLUE.mp4
# Directory in Minutes = 43
# -------------------1 / 2----------------------
# --- Estimate Fri Jan 10 05:40:14 2020
# FileDuration --- /Users/sjegan/Downloads/DownloadStar/Grimm.S01E15.720p.BluRay.X264-CLUE.mp4 = 43
# ffmpeg -i /Users/sjegan/Downloads/DownloadStar/Grimm.S01E15.720p.BluRay.X264-CLUE.mp4 -af apad -shortest -avoid_negative_ts make_zero -fflags +genpts -vcodec libx264 -acodec aac -preset faster -tune film -strict -2 -filter:v scale=640:trunc(ow/a/2)*2 -b:v 128k -b:a 100k -r 20 -map 0:v:0 -map 0:a:0 /Users/sjegan/Downloads/dest/Grimm.S01E15.720p.BluRay.X264-CLUE.mp4
# ---- /Users/sjegan/Downloads/dest/Grimm.S01E15.720p.BluRay.X264-CLUE.mp4 --- 390.5471489429474 seconds ---
# http://94.130.23.244/Grimm.S01E16.720p.BluRay.X264-CLUE.mp4
# Directory in Minutes = 43
# -------------------1 / 2----------------------
# --- Estimate Fri Jan 10 05:48:51 2020
# FileDuration --- /Users/sjegan/Downloads/DownloadStar/Grimm.S01E16.720p.BluRay.X264-CLUE.mp4 = 43
# ffmpeg -i /Users/sjegan/Downloads/DownloadStar/Grimm.S01E16.720p.BluRay.X264-CLUE.mp4 -af apad -shortest -avoid_negative_ts make_zero -fflags +genpts -vcodec libx264 -acodec aac -preset faster -tune film -strict -2 -filter:v scale=640:trunc(ow/a/2)*2 -b:v 128k -b:a 100k -r 20 -map 0:v:0 -map 0:a:0 /Users/sjegan/Downloads/dest/Grimm.S01E16.720p.BluRay.X264-CLUE.mp4
# ---- /Users/sjegan/Downloads/dest/Grimm.S01E16.720p.BluRay.X264-CLUE.mp4 --- 358.3876883983612 seconds ---
# http://94.130.23.244/Grimm.S01E17.720p.BluRay.X264-CLUE.mp4
# Directory in Minutes = 43
# -------------------1 / 2----------------------
# --- Estimate Fri Jan 10 05:57:25 2020
# FileDuration --- /Users/sjegan/Downloads/DownloadStar/Grimm.S01E17.720p.BluRay.X264-CLUE.mp4 = 43
# ffmpeg -i /Users/sjegan/Downloads/DownloadStar/Grimm.S01E17.720p.BluRay.X264-CLUE.mp4 -af apad -shortest -avoid_negative_ts make_zero -fflags +genpts -vcodec libx264 -acodec aac -preset faster -tune film -strict -2 -filter:v scale=640:trunc(ow/a/2)*2 -b:v 128k -b:a 100k -r 20 -map 0:v:0 -map 0:a:0 /Users/sjegan/Downloads/dest/Grimm.S01E17.720p.BluRay.X264-CLUE.mp4
# ---- /Users/sjegan/Downloads/dest/Grimm.S01E17.720p.BluRay.X264-CLUE.mp4 --- 493.23421812057495 seconds ---
# http://94.130.23.244/Grimm.S01E18.720p.BluRay.X264-CLUE.mp4
# Directory in Minutes = 43
# -------------------1 / 2----------------------
# --- Estimate Fri Jan 10 06:07:59 2020
# FileDuration --- /Users/sjegan/Downloads/DownloadStar/Grimm.S01E18.720p.BluRay.X264-CLUE.mp4 = 43
# ffmpeg -i /Users/sjegan/Downloads/DownloadStar/Grimm.S01E18.720p.BluRay.X264-CLUE.mp4 -af apad -shortest -avoid_negative_ts make_zero -fflags +genpts -vcodec libx264 -acodec aac -preset faster -tune film -strict -2 -filter:v scale=640:trunc(ow/a/2)*2 -b:v 128k -b:a 100k -r 20 -map 0:v:0 -map 0:a:0 /Users/sjegan/Downloads/dest/Grimm.S01E18.720p.BluRay.X264-CLUE.mp4
# ---- /Users/sjegan/Downloads/dest/Grimm.S01E18.720p.BluRay.X264-CLUE.mp4 --- 463.79889583587646 seconds ---
# http://94.130.23.244/Grimm.S01E19.720p.BluRay.X264-CLUE.mp4
# Directory in Minutes = 43
# -------------------1 / 2----------------------
# --- Estimate Fri Jan 10 06:17:30 2020
# FileDuration --- /Users/sjegan/Downloads/DownloadStar/Grimm.S01E19.720p.BluRay.X264-CLUE.mp4 = 43
# ffmpeg -i /Users/sjegan/Downloads/DownloadStar/Grimm.S01E19.720p.BluRay.X264-CLUE.mp4 -af apad -shortest -avoid_negative_ts make_zero -fflags +genpts -vcodec libx264 -acodec aac -preset faster -tune film -strict -2 -filter:v scale=640:trunc(ow/a/2)*2 -b:v 128k -b:a 100k -r 20 -map 0:v:0 -map 0:a:0 /Users/sjegan/Downloads/dest/Grimm.S01E19.720p.BluRay.X264-CLUE.mp4
# ---- /Users/sjegan/Downloads/dest/Grimm.S01E19.720p.BluRay.X264-CLUE.mp4 --- 463.35710883140564 seconds ---
# http://94.130.23.244/Grimm.S01E20.720p.BluRay.X264-CLUE.mp4
# Directory in Minutes = 43
# -------------------1 / 2----------------------
# --- Estimate Fri Jan 10 06:28:37 2020
# FileDuration --- /Users/sjegan/Downloads/DownloadStar/Grimm.S01E20.720p.BluRay.X264-CLUE.mp4 = 43
# ffmpeg -i /Users/sjegan/Downloads/DownloadStar/Grimm.S01E20.720p.BluRay.X264-CLUE.mp4 -af apad -shortest -avoid_negative_ts make_zero -fflags +genpts -vcodec libx264 -acodec aac -preset faster -tune film -strict -2 -filter:v scale=640:trunc(ow/a/2)*2 -b:v 128k -b:a 100k -r 20 -map 0:v:0 -map 0:a:0 /Users/sjegan/Downloads/dest/Grimm.S01E20.720p.BluRay.X264-CLUE.mp4
# ---- /Users/sjegan/Downloads/dest/Grimm.S01E20.720p.BluRay.X264-CLUE.mp4 --- 503.54330492019653 seconds ---
# http://94.130.23.244/Grimm.S01E21.720p.BluRay.X264-CLUE.mp4
# Directory in Minutes = 43
# -------------------1 / 2----------------------
# --- Estimate Fri Jan 10 06:39:24 2020
# FileDuration --- /Users/sjegan/Downloads/DownloadStar/Grimm.S01E21.720p.BluRay.X264-CLUE.mp4 = 43
# ffmpeg -i /Users/sjegan/Downloads/DownloadStar/Grimm.S01E21.720p.BluRay.X264-CLUE.mp4 -af apad -shortest -avoid_negative_ts make_zero -fflags +genpts -vcodec libx264 -acodec aac -preset faster -tune film -strict -2 -filter:v scale=640:trunc(ow/a/2)*2 -b:v 128k -b:a 100k -r 20 -map 0:v:0 -map 0:a:0 /Users/sjegan/Downloads/dest/Grimm.S01E21.720p.BluRay.X264-CLUE.mp4
# ---- /Users/sjegan/Downloads/dest/Grimm.S01E21.720p.BluRay.X264-CLUE.mp4 --- 262.9371898174286 seconds ---
# http://94.130.23.244/Grimm.S01E22.720p.BluRay.X264-CLUE.mp4
# Directory in Minutes = 43
# -------------------1 / 2----------------------
# --- Estimate Fri Jan 10 06:45:36 2020
# FileDuration --- /Users/sjegan/Downloads/DownloadStar/Grimm.S01E22.720p.BluRay.X264-CLUE.mp4 = 43
# ffmpeg -i /Users/sjegan/Downloads/DownloadStar/Grimm.S01E22.720p.BluRay.X264-CLUE.mp4 -af apad -shortest -avoid_negative_ts make_zero -fflags +genpts -vcodec libx264 -acodec aac -preset faster -tune film -strict -2 -filter:v scale=640:trunc(ow/a/2)*2 -b:v 128k -b:a 100k -r 20 -map 0:v:0 -map 0:a:0 /Users/sjegan/Downloads/dest/Grimm.S01E22.720p.BluRay.X264-CLUE.mp4
# ---- /Users/sjegan/Downloads/dest/Grimm.S01E22.720p.BluRay.X264-CLUE.mp4 --- 259.0569951534271 seconds ---
# <urllib3.response.HTTPResponse object at 0x10769df60>
# http://94.130.23.244/Grimm.S02E11.To.Protect.And.Serve.Man.720p.WEB-DL.DD5.1.H.264-ECI.mp4
# Directory in Minutes = 43
# -------------------1 / 2----------------------
# --- Estimate Fri Jan 10 06:51:51 2020
# FileDuration --- /Users/sjegan/Downloads/DownloadStar/Grimm.S02E11.To.Protect.And.Serve.Man.720p.WEB-DL.DD5.1.H.264-ECI.mp4 = 43
# ffmpeg -i /Users/sjegan/Downloads/DownloadStar/Grimm.S02E11.To.Protect.And.Serve.Man.720p.WEB-DL.DD5.1.H.264-ECI.mp4 -af apad -shortest -avoid_negative_ts make_zero -fflags +genpts -vcodec libx264 -acodec aac -preset faster -tune film -strict -2 -filter:v scale=640:trunc(ow/a/2)*2 -b:v 128k -b:a 100k -r 20 -map 0:v:0 -map 0:a:0 /Users/sjegan/Downloads/dest/Grimm.S02E11.To.Protect.And.Serve.Man.720p.WEB-DL.DD5.1.H.264-ECI.mp4
# ---- /Users/sjegan/Downloads/dest/Grimm.S02E11.To.Protect.And.Serve.Man.720p.WEB-DL.DD5.1.H.264-ECI.mp4 --- 240.5734887123108 seconds ---
# http://94.130.23.244/Grimm.S02E12.Season.Of.The.Hexenbiest.720p.WEB-DL.DD5.1.H.264-ECI.mp4
# Directory in Minutes = 43
# -------------------1 / 2----------------------
# --- Estimate Fri Jan 10 06:59:02 2020
# FileDuration --- /Users/sjegan/Downloads/DownloadStar/Grimm.S02E12.Season.Of.The.Hexenbiest.720p.WEB-DL.DD5.1.H.264-ECI.mp4 = 43
# ffmpeg -i /Users/sjegan/Downloads/DownloadStar/Grimm.S02E12.Season.Of.The.Hexenbiest.720p.WEB-DL.DD5.1.H.264-ECI.mp4 -af apad -shortest -avoid_negative_ts make_zero -fflags +genpts -vcodec libx264 -acodec aac -preset faster -tune film -strict -2 -filter:v scale=640:trunc(ow/a/2)*2 -b:v 128k -b:a 100k -r 20 -map 0:v:0 -map 0:a:0 /Users/sjegan/Downloads/dest/Grimm.S02E12.Season.Of.The.Hexenbiest.720p.WEB-DL.DD5.1.H.264-ECI.mp4
# ---- /Users/sjegan/Downloads/dest/Grimm.S02E12.Season.Of.The.Hexenbiest.720p.WEB-DL.DD5.1.H.264-ECI.mp4 --- 236.1561999320984 seconds ---
# http://94.130.23.244/Grimm.S02E13.Face.Off.720p.WEB-DL.DD5.1.H.264-ECI.mp4
# Directory in Minutes = 43
# -------------------1 / 2----------------------
# --- Estimate Fri Jan 10 07:06:00 2020
# FileDuration --- /Users/sjegan/Downloads/DownloadStar/Grimm.S02E13.Face.Off.720p.WEB-DL.DD5.1.H.264-ECI.mp4 = 43
# ffmpeg -i /Users/sjegan/Downloads/DownloadStar/Grimm.S02E13.Face.Off.720p.WEB-DL.DD5.1.H.264-ECI.mp4 -af apad -shortest -avoid_negative_ts make_zero -fflags +genpts -vcodec libx264 -acodec aac -preset faster -tune film -strict -2 -filter:v scale=640:trunc(ow/a/2)*2 -b:v 128k -b:a 100k -r 20 -map 0:v:0 -map 0:a:0 /Users/sjegan/Downloads/dest/Grimm.S02E13.Face.Off.720p.WEB-DL.DD5.1.H.264-ECI.mp4
# ---- /Users/sjegan/Downloads/dest/Grimm.S02E13.Face.Off.720p.WEB-DL.DD5.1.H.264-ECI.mp4 --- 240.36850571632385 seconds ---
# http://94.130.23.244/Grimm.S02E14.Natural.Born.Wesen.720p.WEB-DL.DD5.1.H.264-ECI.mp4
# http://94.130.23.244/Grimm.S02E15.Mr.Sandman.720p.WEB-DL.DD5.1.H.264-ECI.mp4
# Directory in Minutes = 43
# -------------------1 / 2----------------------
# --- Estimate Fri Jan 10 07:14:34 2020
# FileDuration --- /Users/sjegan/Downloads/DownloadStar/Grimm.S02E15.Mr.Sandman.720p.WEB-DL.DD5.1.H.264-ECI.mp4 = 43
# ffmpeg -i /Users/sjegan/Downloads/DownloadStar/Grimm.S02E15.Mr.Sandman.720p.WEB-DL.DD5.1.H.264-ECI.mp4 -af apad -shortest -avoid_negative_ts make_zero -fflags +genpts -vcodec libx264 -acodec aac -preset faster -tune film -strict -2 -filter:v scale=640:trunc(ow/a/2)*2 -b:v 128k -b:a 100k -r 20 -map 0:v:0 -map 0:a:0 /Users/sjegan/Downloads/dest/Grimm.S02E15.Mr.Sandman.720p.WEB-DL.DD5.1.H.264-ECI.mp4
# ---- /Users/sjegan/Downloads/dest/Grimm.S02E15.Mr.Sandman.720p.WEB-DL.DD5.1.H.264-ECI.mp4 --- 443.03141379356384 seconds ---
# http://94.130.23.244/Grimm.S02E16.Nameless.720p.WEB-DL.DD5.1.H.264-ECI.mp4
# Directory in Minutes = 43
# -------------------1 / 2----------------------
# --- Estimate Fri Jan 10 07:24:50 2020
# FileDuration --- /Users/sjegan/Downloads/DownloadStar/Grimm.S02E16.Nameless.720p.WEB-DL.DD5.1.H.264-ECI.mp4 = 43
# ffmpeg -i /Users/sjegan/Downloads/DownloadStar/Grimm.S02E16.Nameless.720p.WEB-DL.DD5.1.H.264-ECI.mp4 -af apad -shortest -avoid_negative_ts make_zero -fflags +genpts -vcodec libx264 -acodec aac -preset faster -tune film -strict -2 -filter:v scale=640:trunc(ow/a/2)*2 -b:v 128k -b:a 100k -r 20 -map 0:v:0 -map 0:a:0 /Users/sjegan/Downloads/dest/Grimm.S02E16.Nameless.720p.WEB-DL.DD5.1.H.264-ECI.mp4
# ---- /Users/sjegan/Downloads/dest/Grimm.S02E16.Nameless.720p.WEB-DL.DD5.1.H.264-ECI.mp4 --- 279.0885970592499 seconds ---
# http://94.130.23.244/Grimm.S02E17.One.Angry.Fuchsbau.720p.WEB-DL.DD5.1.H.264-ECI.mp4
# Directory in Minutes = 43
# -------------------1 / 2----------------------
# --- Estimate Fri Jan 10 07:31:49 2020
# FileDuration --- /Users/sjegan/Downloads/DownloadStar/Grimm.S02E17.One.Angry.Fuchsbau.720p.WEB-DL.DD5.1.H.264-ECI.mp4 = 43
# ffmpeg -i /Users/sjegan/Downloads/DownloadStar/Grimm.S02E17.One.Angry.Fuchsbau.720p.WEB-DL.DD5.1.H.264-ECI.mp4 -af apad -shortest -avoid_negative_ts make_zero -fflags +genpts -vcodec libx264 -acodec aac -preset faster -tune film -strict -2 -filter:v scale=640:trunc(ow/a/2)*2 -b:v 128k -b:a 100k -r 20 -map 0:v:0 -map 0:a:0 /Users/sjegan/Downloads/dest/Grimm.S02E17.One.Angry.Fuchsbau.720p.WEB-DL.DD5.1.H.264-ECI.mp4
# ---- /Users/sjegan/Downloads/dest/Grimm.S02E17.One.Angry.Fuchsbau.720p.WEB-DL.DD5.1.H.264-ECI.mp4 --- 443.6685869693756 seconds ---
# http://94.130.23.244/Grimm.S02E18.Ring.Of.Fire.720p.WEB-DL.DD5.1.H.264-ECI.mp4
# Directory in Minutes = 43
# -------------------1 / 2----------------------
# --- Estimate Fri Jan 10 07:41:09 2020
# FileDuration --- /Users/sjegan/Downloads/DownloadStar/Grimm.S02E18.Ring.Of.Fire.720p.WEB-DL.DD5.1.H.264-ECI.mp4 = 43
# ffmpeg -i /Users/sjegan/Downloads/DownloadStar/Grimm.S02E18.Ring.Of.Fire.720p.WEB-DL.DD5.1.H.264-ECI.mp4 -af apad -shortest -avoid_negative_ts make_zero -fflags +genpts -vcodec libx264 -acodec aac -preset faster -tune film -strict -2 -filter:v scale=640:trunc(ow/a/2)*2 -b:v 128k -b:a 100k -r 20 -map 0:v:0 -map 0:a:0 /Users/sjegan/Downloads/dest/Grimm.S02E18.Ring.Of.Fire.720p.WEB-DL.DD5.1.H.264-ECI.mp4
# ---- /Users/sjegan/Downloads/dest/Grimm.S02E18.Ring.Of.Fire.720p.WEB-DL.DD5.1.H.264-ECI.mp4 --- 248.0395209789276 seconds ---
# http://94.130.23.244/Grimm.S02E19.Endangered.720p.WEB-DL.DD5.1.H.264-ECI.mp4
# Directory in Minutes = 43
# -------------------1 / 2----------------------
# --- Estimate Fri Jan 10 07:49:01 2020
# FileDuration --- /Users/sjegan/Downloads/DownloadStar/Grimm.S02E19.Endangered.720p.WEB-DL.DD5.1.H.264-ECI.mp4 = 43
# ffmpeg -i /Users/sjegan/Downloads/DownloadStar/Grimm.S02E19.Endangered.720p.WEB-DL.DD5.1.H.264-ECI.mp4 -af apad -shortest -avoid_negative_ts make_zero -fflags +genpts -vcodec libx264 -acodec aac -preset faster -tune film -strict -2 -filter:v scale=640:trunc(ow/a/2)*2 -b:v 128k -b:a 100k -r 20 -map 0:v:0 -map 0:a:0 /Users/sjegan/Downloads/dest/Grimm.S02E19.Endangered.720p.WEB-DL.DD5.1.H.264-ECI.mp4
# ---- /Users/sjegan/Downloads/dest/Grimm.S02E19.Endangered.720p.WEB-DL.DD5.1.H.264-ECI.mp4 --- 495.96109795570374 seconds ---
# http://94.130.23.244/Grimm.S02E20.Kiss.The.Muse.720p.WEB-DL.DD5.1.H.264-ECI.mp4
# Directory in Minutes = 43
# -------------------1 / 2----------------------
# --- Estimate Fri Jan 10 07:59:16 2020
# FileDuration --- /Users/sjegan/Downloads/DownloadStar/Grimm.S02E20.Kiss.The.Muse.720p.WEB-DL.DD5.1.H.264-ECI.mp4 = 43
# ffmpeg -i /Users/sjegan/Downloads/DownloadStar/Grimm.S02E20.Kiss.The.Muse.720p.WEB-DL.DD5.1.H.264-ECI.mp4 -af apad -shortest -avoid_negative_ts make_zero -fflags +genpts -vcodec libx264 -acodec aac -preset faster -tune film -strict -2 -filter:v scale=640:trunc(ow/a/2)*2 -b:v 128k -b:a 100k -r 20 -map 0:v:0 -map 0:a:0 /Users/sjegan/Downloads/dest/Grimm.S02E20.Kiss.The.Muse.720p.WEB-DL.DD5.1.H.264-ECI.mp4
# ---- /Users/sjegan/Downloads/dest/Grimm.S02E20.Kiss.The.Muse.720p.WEB-DL.DD5.1.H.264-ECI.mp4 --- 268.57716131210327 seconds ---
# http://94.130.23.244/Grimm.S02E21.The.Waking.Dead.720p.WEB-DL.DD5.1.H.264-ECI.mp4
# Directory in Minutes = 43
# -------------------1 / 2----------------------
# --- Estimate Fri Jan 10 08:06:54 2020
# FileDuration --- /Users/sjegan/Downloads/DownloadStar/Grimm.S02E21.The.Waking.Dead.720p.WEB-DL.DD5.1.H.264-ECI.mp4 = 43
# ffmpeg -i /Users/sjegan/Downloads/DownloadStar/Grimm.S02E21.The.Waking.Dead.720p.WEB-DL.DD5.1.H.264-ECI.mp4 -af apad -shortest -avoid_negative_ts make_zero -fflags +genpts -vcodec libx264 -acodec aac -preset faster -tune film -strict -2 -filter:v scale=640:trunc(ow/a/2)*2 -b:v 128k -b:a 100k -r 20 -map 0:v:0 -map 0:a:0 /Users/sjegan/Downloads/dest/Grimm.S02E21.The.Waking.Dead.720p.WEB-DL.DD5.1.H.264-ECI.mp4
# ---- /Users/sjegan/Downloads/dest/Grimm.S02E21.The.Waking.Dead.720p.WEB-DL.DD5.1.H.264-ECI.mp4 --- 475.3994860649109 seconds ---
# http://94.130.23.244/Grimm.S02E22.Goodnight.Sweet.Grimm.720p.WEB-DL.DD5.1.H.264-ECI.mp4
# Directory in Minutes = 43
# -------------------1 / 2----------------------
# --- Estimate Fri Jan 10 08:50:19 2020
# FileDuration --- /Users/sjegan/Downloads/DownloadStar/Grimm.S02E22.Goodnight.Sweet.Grimm.720p.WEB-DL.DD5.1.H.264-ECI.mp4 = 43
# ffmpeg -i /Users/sjegan/Downloads/DownloadStar/Grimm.S02E22.Goodnight.Sweet.Grimm.720p.WEB-DL.DD5.1.H.264-ECI.mp4 -af apad -shortest -avoid_negative_ts make_zero -fflags +genpts -vcodec libx264 -acodec aac -preset faster -tune film -strict -2 -filter:v scale=640:trunc(ow/a/2)*2 -b:v 128k -b:a 100k -r 20 -map 0:v:0 -map 0:a:0 /Users/sjegan/Downloads/dest/Grimm.S02E22.Goodnight.Sweet.Grimm.720p.WEB-DL.DD5.1.H.264-ECI.mp4
# ---- /Users/sjegan/Downloads/dest/Grimm.S02E22.Goodnight.Sweet.Grimm.720p.WEB-DL.DD5.1.H.264-ECI.mp4 --- 253.3992350101471 seconds ---
# <urllib3.response.HTTPResponse object at 0x104113898>
# http://94.130.23.244/grimm.s03e11.720p.bluray.x264-demand.mp4
# Directory in Minutes = 43
# -------------------1 / 2----------------------
# --- Estimate Fri Jan 10 09:00:30 2020
# FileDuration --- /Users/sjegan/Downloads/DownloadStar/grimm.s03e11.720p.bluray.x264-demand.mp4 = 43
# ffmpeg -i /Users/sjegan/Downloads/DownloadStar/grimm.s03e11.720p.bluray.x264-demand.mp4 -af apad -shortest -avoid_negative_ts make_zero -fflags +genpts -vcodec libx264 -acodec aac -preset faster -tune film -strict -2 -filter:v scale=640:trunc(ow/a/2)*2 -b:v 128k -b:a 100k -r 20 -map 0:v:0 -map 0:a:0 /Users/sjegan/Downloads/dest/grimm.s03e11.720p.bluray.x264-demand.mp4
# ---- /Users/sjegan/Downloads/dest/grimm.s03e11.720p.bluray.x264-demand.mp4 --- 422.14726877212524 seconds ---
# http://94.130.23.244/grimm.s03e12.720p.bluray.x264-demand.mp4
# Directory in Minutes = 43
# -------------------1 / 2----------------------
# --- Estimate Fri Jan 10 09:15:42 2020
# FileDuration --- /Users/sjegan/Downloads/DownloadStar/grimm.s03e12.720p.bluray.x264-demand.mp4 = 43
# ffmpeg -i /Users/sjegan/Downloads/DownloadStar/grimm.s03e12.720p.bluray.x264-demand.mp4 -af apad -shortest -avoid_negative_ts make_zero -fflags +genpts -vcodec libx264 -acodec aac -preset faster -tune film -strict -2 -filter:v scale=640:trunc(ow/a/2)*2 -b:v 128k -b:a 100k -r 20 -map 0:v:0 -map 0:a:0 /Users/sjegan/Downloads/dest/grimm.s03e12.720p.bluray.x264-demand.mp4
# ---- /Users/sjegan/Downloads/dest/grimm.s03e12.720p.bluray.x264-demand.mp4 --- 247.4880828857422 seconds ---
# http://94.130.23.244/grimm.s03e13.720p.bluray.x264-demand.mp4
# Directory in Minutes = 43
# -------------------1 / 2----------------------
# --- Estimate Fri Jan 10 09:26:18 2020
# FileDuration --- /Users/sjegan/Downloads/DownloadStar/grimm.s03e13.720p.bluray.x264-demand.mp4 = 43
# ffmpeg -i /Users/sjegan/Downloads/DownloadStar/grimm.s03e13.720p.bluray.x264-demand.mp4 -af apad -shortest -avoid_negative_ts make_zero -fflags +genpts -vcodec libx264 -acodec aac -preset faster -tune film -strict -2 -filter:v scale=640:trunc(ow/a/2)*2 -b:v 128k -b:a 100k -r 20 -map 0:v:0 -map 0:a:0 /Users/sjegan/Downloads/dest/grimm.s03e13.720p.bluray.x264-demand.mp4
# ---- /Users/sjegan/Downloads/dest/grimm.s03e13.720p.bluray.x264-demand.mp4 --- 261.87329506874084 seconds ---
# http://94.130.23.244/grimm.s03e14.720p.bluray.x264-demand.mp4
# Directory in Minutes = 43
# -------------------1 / 2----------------------
# --- Estimate Fri Jan 10 09:36:12 2020
# FileDuration --- /Users/sjegan/Downloads/DownloadStar/grimm.s03e14.720p.bluray.x264-demand.mp4 = 43
# ffmpeg -i /Users/sjegan/Downloads/DownloadStar/grimm.s03e14.720p.bluray.x264-demand.mp4 -af apad -shortest -avoid_negative_ts make_zero -fflags +genpts -vcodec libx264 -acodec aac -preset faster -tune film -strict -2 -filter:v scale=640:trunc(ow/a/2)*2 -b:v 128k -b:a 100k -r 20 -map 0:v:0 -map 0:a:0 /Users/sjegan/Downloads/dest/grimm.s03e14.720p.bluray.x264-demand.mp4
# ---- /Users/sjegan/Downloads/dest/grimm.s03e14.720p.bluray.x264-demand.mp4 --- 501.77963495254517 seconds ---
# http://94.130.23.244/grimm.s03e15.720p.bluray.x264-demand.mp4
# Directory in Minutes = 43
# -------------------1 / 2----------------------
# --- Estimate Fri Jan 10 10:27:24 2020
# FileDuration --- /Users/sjegan/Downloads/DownloadStar/grimm.s03e15.720p.bluray.x264-demand.mp4 = 43
# ffmpeg -i /Users/sjegan/Downloads/DownloadStar/grimm.s03e15.720p.bluray.x264-demand.mp4 -af apad -shortest -avoid_negative_ts make_zero -fflags +genpts -vcodec libx264 -acodec aac -preset faster -tune film -strict -2 -filter:v scale=640:trunc(ow/a/2)*2 -b:v 128k -b:a 100k -r 20 -map 0:v:0 -map 0:a:0 /Users/sjegan/Downloads/dest/grimm.s03e15.720p.bluray.x264-demand.mp4
# ---- /Users/sjegan/Downloads/dest/grimm.s03e15.720p.bluray.x264-demand.mp4 --- 240.23893523216248 seconds ---
# http://94.130.23.244/grimm.s03e16.720p.bluray.x264-demand.mp4
# Directory in Minutes = 43
# -------------------1 / 2----------------------
# --- Estimate Fri Jan 10 10:42:08 2020
# FileDuration --- /Users/sjegan/Downloads/DownloadStar/grimm.s03e16.720p.bluray.x264-demand.mp4 = 43
# ffmpeg -i /Users/sjegan/Downloads/DownloadStar/grimm.s03e16.720p.bluray.x264-demand.mp4 -af apad -shortest -avoid_negative_ts make_zero -fflags +genpts -vcodec libx264 -acodec aac -preset faster -tune film -strict -2 -filter:v scale=640:trunc(ow/a/2)*2 -b:v 128k -b:a 100k -r 20 -map 0:v:0 -map 0:a:0 /Users/sjegan/Downloads/dest/grimm.s03e16.720p.bluray.x264-demand.mp4
# ---- /Users/sjegan/Downloads/dest/grimm.s03e16.720p.bluray.x264-demand.mp4 --- 257.3780748844147 seconds ---
# http://94.130.23.244/grimm.s03e17.720p.bluray.x264-demand.mp4
# Directory in Minutes = 42
# -------------------1 / 2----------------------
# --- Estimate Fri Jan 10 11:30:41 2020
# FileDuration --- /Users/sjegan/Downloads/DownloadStar/grimm.s03e17.720p.bluray.x264-demand.mp4 = 42
# ffmpeg -i /Users/sjegan/Downloads/DownloadStar/grimm.s03e17.720p.bluray.x264-demand.mp4 -af apad -shortest -avoid_negative_ts make_zero -fflags +genpts -vcodec libx264 -acodec aac -preset faster -tune film -strict -2 -filter:v scale=640:trunc(ow/a/2)*2 -b:v 128k -b:a 100k -r 20 -map 0:v:0 -map 0:a:0 /Users/sjegan/Downloads/dest/grimm.s03e17.720p.bluray.x264-demand.mp4
# ---- /Users/sjegan/Downloads/dest/grimm.s03e17.720p.bluray.x264-demand.mp4 --- 258.10365986824036 seconds ---
# http://94.130.23.244/grimm.s03e18.720p.bluray.x264-demand.mp4
# Directory in Minutes = 43
# -------------------1 / 2----------------------
# --- Estimate Fri Jan 10 12:01:06 2020
# FileDuration --- /Users/sjegan/Downloads/DownloadStar/grimm.s03e18.720p.bluray.x264-demand.mp4 = 43
# ffmpeg -i /Users/sjegan/Downloads/DownloadStar/grimm.s03e18.720p.bluray.x264-demand.mp4 -af apad -shortest -avoid_negative_ts make_zero -fflags +genpts -vcodec libx264 -acodec aac -preset faster -tune film -strict -2 -filter:v scale=640:trunc(ow/a/2)*2 -b:v 128k -b:a 100k -r 20 -map 0:v:0 -map 0:a:0 /Users/sjegan/Downloads/dest/grimm.s03e18.720p.bluray.x264-demand.mp4
# ---- /Users/sjegan/Downloads/dest/grimm.s03e18.720p.bluray.x264-demand.mp4 --- 251.3808319568634 seconds ---
# http://94.130.23.244/grimm.s03e19.720p.bluray.x264-demand.mp4
# Directory in Minutes = 43
# -------------------1 / 2----------------------
# --- Estimate Fri Jan 10 12:15:31 2020
# FileDuration --- /Users/sjegan/Downloads/DownloadStar/grimm.s03e19.720p.bluray.x264-demand.mp4 = 43
# ffmpeg -i /Users/sjegan/Downloads/DownloadStar/grimm.s03e19.720p.bluray.x264-demand.mp4 -af apad -shortest -avoid_negative_ts make_zero -fflags +genpts -vcodec libx264 -acodec aac -preset faster -tune film -strict -2 -filter:v scale=640:trunc(ow/a/2)*2 -b:v 128k -b:a 100k -r 20 -map 0:v:0 -map 0:a:0 /Users/sjegan/Downloads/dest/grimm.s03e19.720p.bluray.x264-demand.mp4
# ---- /Users/sjegan/Downloads/dest/grimm.s03e19.720p.bluray.x264-demand.mp4 --- 304.61802196502686 seconds ---
# http://94.130.23.244/grimm.s03e20.720p.bluray.x264-demand.mp4
# Directory in Minutes = 43
# -------------------1 / 2----------------------
# --- Estimate Fri Jan 10 12:37:50 2020
# FileDuration --- /Users/sjegan/Downloads/DownloadStar/grimm.s03e20.720p.bluray.x264-demand.mp4 = 43
# ffmpeg -i /Users/sjegan/Downloads/DownloadStar/grimm.s03e20.720p.bluray.x264-demand.mp4 -af apad -shortest -avoid_negative_ts make_zero -fflags +genpts -vcodec libx264 -acodec aac -preset faster -tune film -strict -2 -filter:v scale=640:trunc(ow/a/2)*2 -b:v 128k -b:a 100k -r 20 -map 0:v:0 -map 0:a:0 /Users/sjegan/Downloads/dest/grimm.s03e20.720p.bluray.x264-demand.mp4
# ---- /Users/sjegan/Downloads/dest/grimm.s03e20.720p.bluray.x264-demand.mp4 --- 292.0748550891876 seconds ---
# http://94.130.23.244/grimm.s03e21.720p.bluray.x264-demand.mp4
